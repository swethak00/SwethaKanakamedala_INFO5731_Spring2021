# %% [markdown]
# <a href="https://colab.research.google.com/github/swethak00/SwethaKanakamedala_INFO5731_Spring2021/blob/main/Copy_of_In_class_exercise_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The fourth in-class-exercise (20 points in total, 2/9/2021)**

# %% [markdown]
# # 1. Text Data Preprocessing
#
# Here is a [legal case](https://github.com/unt-iialab/info5731_spring2021/blob/main/class_exercises/01-05-1%20%20Adams%20v%20Tanner.txt) we collected from westlaw, please follow the steps we mentioned in lesson 5 to clean the data:
#
#
#
# ## 1.1 Basic feature extraction using text data (4 points)
#
# *   Number of sentences
# *   Number of words
# *   Number of characters
# *   Average word length
# *   Number of stopwords
# *   Number of special characters
# *   Number of numerics
# *   Number of uppercase words
#
# ## 1.2 Basic Text Pre-processing of text data (4 points)
#
# *   Lower casing
# *   Punctuation removal
# *   Stopwords removal
# *   Frequent words removal
# *   Rare words removal
# *   Spelling correction
# *   Tokenization
# *   Stemming
# *   Lemmatization
#
# ## 1.3 Save all the **clean sentences** to a **csv file** (one column, each raw is a sentence) after finishing all the steps above. (4 points)
#
#
# ## 1.4 Advance Text Processing (Extra credit: 4 points)
#
# *   Calculate the term frequency of all the terms.
# *   Print out top 10 1-gram, top 10 2-grams, and top 10 3-grams terms as features.

# %%
from six.moves import urllib
import pandas as pd

text_array = []
url = "https://raw.githubusercontent.com/unt-iialab/info5731_spring2021/main/class_exercises/01-05-1%20%20Adams%20v%20Tanner.txt"
text_file = urllib.request.urlopen(url)

for line in text_file:
  decoded_data = line.decode("utf-8").replace('\r\n', '')
  if decoded_data: text_array.append(decoded_data)
file = pd.DataFrame (text_array, columns = ['Raw Text'])
print(file)
# Out:
#                                               Raw Text
# 0                                           5 Ala. 740
# 1                            Supreme Court of Alabama.
# 2                                                ADAMS
# 3                                                   v.
# 4                                   TANNER AND HORTON.
# ..                                                 ...
# 143            There are no Filings for this citation.
# 144                                 Negative Treatment
# 145  There are no Negative Treatment results for th...
# 146                                            History
# 147    There are no History results for this citation.
#
# [148 rows x 1 columns]

# %% [markdown]
# Number of Sentences.

# %%
file['Number of Sentences'] = file['Raw Text'].apply(lambda x: len(str(x).split(".")))
file
# Out:
#                                               Raw Text  Number of Sentences
# 0                                           5 Ala. 740                    2
# 1                            Supreme Court of Alabama.                    2
# 2                                                ADAMS                    1
# 3                                                   v.                    2
# 4                                   TANNER AND HORTON.                    2
# ..                                                 ...                  ...
# 143            There are no Filings for this citation.                    2
# 144                                 Negative Treatment                    1
# 145  There are no Negative Treatment results for th...                    2
# 146                                            History                    1
# 147    There are no History results for this citation.                    2
#
# [148 rows x 2 columns]

# %% [markdown]
# Number of Words

# %%
file['Number of Words'] = file['Raw Text'].apply(lambda x: len(str(x).split(" ")))
file
# Out:
#                                               Raw Text  ...  Number of Words
# 0                                           5 Ala. 740  ...                3
# 1                            Supreme Court of Alabama.  ...                4
# 2                                                ADAMS  ...                1
# 3                                                   v.  ...                1
# 4                                   TANNER AND HORTON.  ...                3
# ..                                                 ...  ...              ...
# 143            There are no Filings for this citation.  ...                7
# 144                                 Negative Treatment  ...                2
# 145  There are no Negative Treatment results for th...  ...                9
# 146                                            History  ...                1
# 147    There are no History results for this citation.  ...                8
#
# [148 rows x 3 columns]

# %% [markdown]
# Number of Characters

# %%
file['Number of Characters'] = file['Raw Text'].str.len()
file
# Out:
#                                               Raw Text  ...  Number of Characters
# 0                                           5 Ala. 740  ...                    10
# 1                            Supreme Court of Alabama.  ...                    25
# 2                                                ADAMS  ...                     5
# 3                                                   v.  ...                     2
# 4                                   TANNER AND HORTON.  ...                    18
# ..                                                 ...  ...                   ...
# 143            There are no Filings for this citation.  ...                    39
# 144                                 Negative Treatment  ...                    18
# 145  There are no Negative Treatment results for th...  ...                    58
# 146                                            History  ...                     7
# ...

# %% [markdown]
# Average word length

# %%
def avg_word_length(sentence):
  words = sentence.split()
  if len(words) != 0:
    return(sum(len(word) for word in words)/len(words))
  else:
    return None

file['Average Word Length'] = file['Raw Text'].apply(lambda x: avg_word_length(x))
file
# Out:
#                                               Raw Text  ...  Average Word Length
# 0                                           5 Ala. 740  ...             2.666667
# 1                            Supreme Court of Alabama.  ...             5.500000
# 2                                                ADAMS  ...             5.000000
# 3                                                   v.  ...             2.000000
# 4                                   TANNER AND HORTON.  ...             5.333333
# ..                                                 ...  ...                  ...
# 143            There are no Filings for this citation.  ...             4.714286
# 144                                 Negative Treatment  ...             8.500000
# 145  There are no Negative Treatment results for th...  ...             5.555556
# 146                                            History  ...             7.000000
# 147    There are no History results for this citation.  ...             5.000000
#
# ...

# %% [markdown]
# Number of stopwords

# %%
from nltk.corpus import stopwords

import nltk
nltk.download('stopwords')

stop = stopwords.words('english')

file['Number of Stopwords'] = file['Raw Text'].apply(lambda x: len([x for x in x.split() if x in stop]))
file
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                               Raw Text  ...  Number of Stopwords
# 0                                           5 Ala. 740  ...                    0
# 1                            Supreme Court of Alabama.  ...                    1
# 2                                                ADAMS  ...                    0
# 3                                                   v.  ...                    0
# 4                                   TANNER AND HORTON.  ...                    0
# ..                                                 ...  ...                  ...
# 143            There are no Filings for this citation.  ...                    4
# 144                                 Negative Treatment  ...                    0
# 145  There are no Negative Treatment results for th...  ...                    4
# ...

# %% [markdown]
# Number of special characters

# %%
def special_characters(sentence):
  special = 0
  for value in range(len(sentence)):
    if not((sentence[value].isalpha()) and (sentence[value].isdigit())):
        special = special + 1
  return special

file['Number of special characters'] = file['Raw Text'].apply(lambda x: special_characters(x))
file
# Out:
#                                               Raw Text  ...  Number of special characters
# 0                                           5 Ala. 740  ...                            10
# 1                            Supreme Court of Alabama.  ...                            25
# 2                                                ADAMS  ...                             5
# 3                                                   v.  ...                             2
# 4                                   TANNER AND HORTON.  ...                            18
# ..                                                 ...  ...                           ...
# 143            There are no Filings for this citation.  ...                            39
# 144                                 Negative Treatment  ...                            18
# 145  There are no Negative Treatment results for th...  ...                            58
# ...

# %% [markdown]
# Number of numerics

# %%
file['Numbers of numerics'] = file['Raw Text'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
file
# Out:
#                                               Raw Text  ...  Numbers of numerics
# 0                                           5 Ala. 740  ...                    2
# 1                            Supreme Court of Alabama.  ...                    0
# 2                                                ADAMS  ...                    0
# 3                                                   v.  ...                    0
# 4                                   TANNER AND HORTON.  ...                    0
# ..                                                 ...  ...                  ...
# 143            There are no Filings for this citation.  ...                    0
# 144                                 Negative Treatment  ...                    0
# 145  There are no Negative Treatment results for th...  ...                    0
# 146                                            History  ...                    0
# 147    There are no History results for this citation.  ...                    0
#
# ...

# %% [markdown]
# Number of uppercase words

# %%
file['Number of upper case words'] = file['Raw Text'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
file
# Out:
#                                               Raw Text  ...  Number of upper case words
# 0                                           5 Ala. 740  ...                           0
# 1                            Supreme Court of Alabama.  ...                           0
# 2                                                ADAMS  ...                           1
# 3                                                   v.  ...                           0
# 4                                   TANNER AND HORTON.  ...                           3
# ..                                                 ...  ...                         ...
# 143            There are no Filings for this citation.  ...                           0
# 144                                 Negative Treatment  ...                           0
# 145  There are no Negative Treatment results for th...  ...                           0
# 146                                            History  ...                           0
# ...

# %% [markdown]
# Lower casing

# %%
file['Lower Case'] = file['Raw Text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
file
# Out:
#                                               Raw Text  ...                                         Lower Case
# 0                                           5 Ala. 740  ...                                         5 ala. 740
# 1                            Supreme Court of Alabama.  ...                          supreme court of alabama.
# 2                                                ADAMS  ...                                              adams
# 3                                                   v.  ...                                                 v.
# 4                                   TANNER AND HORTON.  ...                                 tanner and horton.
# ..                                                 ...  ...                                                ...
# 143            There are no Filings for this citation.  ...            there are no filings for this citation.
# ...

# %% [markdown]
# Punctuation removal

# %%
file['Removal of Punctuation'] = file['Lower Case'].str.replace('[^\w\s]','')
file
# Out:
#                                               Raw Text  ...                             Removal of Punctuation
# 0                                           5 Ala. 740  ...                                          5 ala 740
# 1                            Supreme Court of Alabama.  ...                           supreme court of alabama
# 2                                                ADAMS  ...                                              adams
# 3                                                   v.  ...                                                  v
# 4                                   TANNER AND HORTON.  ...                                  tanner and horton
# ..                                                 ...  ...                                                ...
# 143            There are no Filings for this citation.  ...             there are no filings for this citation
# ...

# %% [markdown]
# Stopwords removal

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
file['Stopwords Removal'] = file['Removal of Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
file
# Out:
#                                               Raw Text  ...                    Stopwords Removal
# 0                                           5 Ala. 740  ...                            5 ala 740
# 1                            Supreme Court of Alabama.  ...                supreme court alabama
# 2                                                ADAMS  ...                                adams
# 3                                                   v.  ...                                    v
# 4                                   TANNER AND HORTON.  ...                        tanner horton
# ..                                                 ...  ...                                  ...
# 143            There are no Filings for this citation.  ...                     filings citation
# 144                                 Negative Treatment  ...                   negative treatment
# 145  There are no Negative Treatment results for th...  ...  negative treatment results citation
# ...

# %% [markdown]
# Frequent words removal

# %%
freq_words = pd.Series(' '.join(file['Stopwords Removal']).split()).value_counts()[:10]
print(freq_words)
freq_words_list = list(freq_words.index)
file['After common words removal'] = file['Stopwords Removal'].apply(lambda x: " ".join(x for x in x.split() if x not in freq_words_list))
file
# Out:
# execution    50
# crop         49
# lien         25
# levy         25
# claimants    22
# v            22
# right        21
# case         21
# court        20
# gathered     19
# dtype: int64
#                                               Raw Text  ...           After common words removal
# 0                                           5 Ala. 740  ...                            5 ala 740
# 1                            Supreme Court of Alabama.  ...                      supreme alabama
# 2                                                ADAMS  ...                                adams
# 3                                                   v.  ...
# 4                                   TANNER AND HORTON.  ...                        tanner horton
# ..                                                 ...  ...                                  ...
# 143            There are no Filings for this citation.  ...                     filings citation
# ...

# %% [markdown]
# Rare words removal

# %%
rare_words = pd.Series(' '.join(file['Stopwords Removal']).split()).value_counts()[-10:]
print(rare_words)
rare_words_list = list(rare_words.index)
file['After Rare Words removal'] = file['After common words removal'].apply(lambda x: " ".join(x for x in x.split() if x not in rare_words_list))
file
# Out:
# tennessee    1
# making       1
# vary         1
# unripe       1
# exposed      1
# giving       1
# amounting    1
# october      1
# secure       1
# reason       1
# dtype: int64
#                                               Raw Text  ...             After Rare Words removal
# 0                                           5 Ala. 740  ...                            5 ala 740
# 1                            Supreme Court of Alabama.  ...                      supreme alabama
# 2                                                ADAMS  ...                                adams
# 3                                                   v.  ...
# 4                                   TANNER AND HORTON.  ...                        tanner horton
# ..                                                 ...  ...                                  ...
# 143            There are no Filings for this citation.  ...                     filings citation
# ...

# %% [markdown]
# Spelling correction

# %%
from textblob import TextBlob
file['Spelling Correction'] = file['After Rare Words removal'].apply(lambda x: str(TextBlob(x).correct()))
file
# Out:
#                                               Raw Text  ...                   Spelling Correction
# 0                                           5 Ala. 740  ...                             5 all 740
# 1                            Supreme Court of Alabama.  ...                       supreme alabama
# 2                                                ADAMS  ...                                 adams
# 3                                                   v.  ...
# 4                                   TANNER AND HORTON.  ...                         manner norton
# ..                                                 ...  ...                                   ...
# 143            There are no Filings for this citation.  ...                      filing situation
# 144                                 Negative Treatment  ...                    negative treatment
# 145  There are no Negative Treatment results for th...  ...  negative treatment results situation
# ...

# %% [markdown]
# Tokenization

# %%
import nltk
nltk.download('punkt')
file['Tokenization'] = file['Spelling Correction'].apply(lambda x: TextBlob(x).words)
file
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                               Raw Text  ...                               Tokenization
# 0                                           5 Ala. 740  ...                              [5, all, 740]
# 1                            Supreme Court of Alabama.  ...                         [supreme, alabama]
# 2                                                ADAMS  ...                                    [adams]
# 3                                                   v.  ...                                         []
# 4                                   TANNER AND HORTON.  ...                           [manner, norton]
# ..                                                 ...  ...                                        ...
# 143            There are no Filings for this citation.  ...                        [filing, situation]
# ...

# %% [markdown]
# Stemming

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
file['After Stemming'] = file['Tokenization'].apply(lambda x: " ".join([st.stem(word) for word in x]))
file
# Out:
#                                               Raw Text  ...               After Stemming
# 0                                           5 Ala. 740  ...                    5 all 740
# 1                            Supreme Court of Alabama.  ...               suprem alabama
# 2                                                ADAMS  ...                         adam
# 3                                                   v.  ...
# 4                                   TANNER AND HORTON.  ...                manner norton
# ..                                                 ...  ...                          ...
# 143            There are no Filings for this citation.  ...                  file situat
# 144                                 Negative Treatment  ...                neg treatment
# 145  There are no Negative Treatment results for th...  ...  neg treatment result situat
# 146                                            History  ...                      histori
# ...

# %% [markdown]
# Lemmatization

# %%
from textblob import Word
import nltk
nltk.download('wordnet')

file['After Lemmatization'] = file['After Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
file
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
#                                               Raw Text  ...          After Lemmatization
# 0                                           5 Ala. 740  ...                    5 all 740
# 1                            Supreme Court of Alabama.  ...               suprem alabama
# 2                                                ADAMS  ...                         adam
# 3                                                   v.  ...
# 4                                   TANNER AND HORTON.  ...                manner norton
# ..                                                 ...  ...                          ...
# 143            There are no Filings for this citation.  ...                  file situat
# 144                                 Negative Treatment  ...                neg treatment
# 145  There are no Negative Treatment results for th...  ...  neg treatment result situat
# ...

# %% [markdown]
# Saving to CSV

# %%
file.to_csv('cleaned_data.csv',index=False)

# %% [markdown]
# Advanced Text Processing

# %%
term_frequency = (file['After Lemmatization']).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
term_frequency.columns = ['words','term_ferquency']
term_frequency
# Out:
#        words  term_ferquency
# 0          5             8.0
# 1        740             2.0
# 2        all            17.0
# 3     suprem             1.0
# 4    alabama             1.0
# ..       ...             ...
# 703    yield             1.0
# 704      six             1.0
# 705     file             2.0
# 706      neg             2.0
# 707  histori             2.0
#
# [708 rows x 2 columns]

# %% [markdown]
# Top 10- 1Grams

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

words_sentence = []
for sentence in file['After Lemmatization']:
  words_sentence.append(word_tokenize(sentence))
aftercleaning = [x for x in words_sentence if x != []]
iterations = list(itertools.chain.from_iterable(aftercleaning))
one_grams = ngrams(iterations, 1)
collections.Counter(one_grams).most_common(10)
# Out:
# [(('law',), 18),
#  (('all',), 17),
#  (('grow',), 17),
#  (('contract',), 16),
#  (('rep',), 16),
#  (('plaintiff',), 15),
#  (('posse',), 14),
#  (('attach',), 14),
#  (('cotton',), 14),
#  (('2',), 13)]

# %% [markdown]
# Top 10- 2Grams

# %%
bi_grams = nltk.bigrams(iterations)
frequency_dist = nltk.FreqDist(bi_grams)
(frequency_dist.most_common(10))
# Out:
# [(('common', 'law'), 7),
#  (('john', 'rep'), 6),
#  (('tri', 'hon'), 6),
#  (('fieri', 'facial'), 5),
#  (('while', 'foot'), 4),
#  (('can', 'not'), 4),
#  (('appeal', 'circuit'), 4),
#  (('error', 'circuit'), 3),
#  (('attach', 'favor'), 3),
#  (('allen', 'harrison'), 3)]

# %% [markdown]
# Top 10- 3Grams

# %%
tri_grams = nltk.trigrams(iterations)
frequency_dist = nltk.FreqDist(tri_grams)
frequency_dist.most_common(10)
# Out:
# [(('2', 'john', 'rep'), 3),
#  (('all', 'grover', 'convers'), 3),
#  (('5', 'all', '740'), 2),
#  (('writ', 'error', 'circuit'), 2),
#  (('interest', 'vest', 'posse'), 2),
#  (('vest', 'posse', 'either'), 2),
#  (('posse', 'either', 'immedi'), 2),
#  (('either', 'immedi', 'futur'), 2),
#  (('immedi', 'futur', 'time'), 2),
#  (('case', 'cite', 'headnot'), 2)]

# %% [markdown]
# # 2. Python Regular Expression

# %% [markdown]
# ## 2.1 Write a Python program to remove leading zeros from an IP address. (4 points)
#
# ip = "260.08.094.109"

# %%
import re
ip = "216.08.094.109"
string = re.sub('\.[0]*', '.', ip)
print(string)
# Out:
# 216.8.94.109

# %% [markdown]
# ## 2.2 Write a Python Program to extract all the years from the following sentence. (4 points)
#
# sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."

# %%
import re
sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."
years = re.findall(r'2\d\d\d', sentence)
print(years)
# Out:
# ['2010', '2010', '2019']
