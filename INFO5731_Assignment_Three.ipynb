# %% [markdown]
# <a href="https://colab.research.google.com/github/swethak00/SwethaKanakamedala_INFO5731_Spring2021/blob/main/INFO5731_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
# Write your code here

# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,995 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [333 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,398 kB]
# Ign:19 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:19 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [603 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,746 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,425 kB]
# Get:22 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [894 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [363 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,165 kB]
# Fetched 12.2 MB in 4s (3,255 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 49 not upgraded.
# Need to get 83.2 MB of archives.
# After this operation, 282 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 89.0.4389.82-0ubuntu0.18.04.1 [1,127 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 89.0.4389.82-0ubuntu0.18.04.1 [73.6 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 89.0.4389.82-0ubuntu0.18.04.1 [3,800 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 89.0.4389.82-0ubuntu0.18.04.1 [4,697 kB]
# Fetched 83.2 MB in 4s (19.0 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 160975 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_89.0.4389.82-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (89.0.4389.82-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_89.0.4389.82-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (89.0.4389.82-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_89.0.4389.82-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (89.0.4389.82-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_89.0.4389.82-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (89.0.4389.82-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (89.0.4389.82-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (89.0.4389.82-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (89.0.4389.82-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (89.0.4389.82-0ubuntu0.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#      |████████████████████████████████| 911kB 5.3MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.24.3)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'
title_array = []
review_array = []
driver.get(link)
for num in range(4):
  driver.find_element_by_class_name("ipl-load-more__button").click()
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(listOfTitle, listOfReviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
df = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 125
#                                                  Title                                             Review
# 0    Outstanding movie with a haunting performance ...  Every once in a while a movie comes, that trul...
# 1                       Only certain people can relate  This is a movie that only those who have felt ...
# 2                             Perfect in every aspect.  Truly a masterpiece, The Best Hollywood film o...
# 3                                        MASTERPIECE 😍  Joaquin Phoenix gives a tour de force performa...
# 4                                     The Hype is real  Most of the time movies are anticipated like t...
# ..                                                 ...                                                ...
# 120  Went into this blind, and i didnt enjoy it at ...  I didnt really know much about this movie. I h...
# 121                                              Great
# 122                                 Very Disappointing  Film was directed and produced poorly. Opportu...
# 123  By far the best DC movie to date, Joaquin Phoe...  Wow, what a movie! I have to admit, When I fir...
# 124                                     Not real Joker  This movie is poorly done as to how it tells t...
#
# [125 rows x 2 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader>  d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Package abc is already up-to-date!
#        | Downloading package alpino to /root/nltk_data...
#        |   Package alpino is already up-to-date!
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Package biocreative_ppi is already up-to-date!
#        | Downloading package brown to /root/nltk_data...
#        |   Package brown is already up-to-date!
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Package brown_tei is already up-to-date!
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Package cess_cat is already up-to-date!
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Package cess_esp is already up-to-date!
#        | Downloading package chat80 to /root/nltk_data...
#        |   Package chat80 is already up-to-date!
#        | Downloading package city_database to /root/nltk_data...
#        |   Package city_database is already up-to-date!
#        | Downloading package cmudict to /root/nltk_data...
#        |   Package cmudict is already up-to-date!
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Package comparative_sentences is already up-to-date!
#        | Downloading package comtrans to /root/nltk_data...
#        |   Package comtrans is already up-to-date!
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Package conll2000 is already up-to-date!
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Package conll2002 is already up-to-date!
#        | Downloading package conll2007 to /root/nltk_data...
#        |   Package conll2007 is already up-to-date!
#        | Downloading package crubadan to /root/nltk_data...
#        |   Package crubadan is already up-to-date!
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Package dependency_treebank is already up-to-date!
#        | Downloading package dolch to /root/nltk_data...
#        |   Package dolch is already up-to-date!
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Package europarl_raw is already up-to-date!
#        | Downloading package floresta to /root/nltk_data...
#        |   Package floresta is already up-to-date!
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Package framenet_v15 is already up-to-date!
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Package framenet_v17 is already up-to-date!
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Package gazetteers is already up-to-date!
#        | Downloading package genesis to /root/nltk_data...
#        |   Package genesis is already up-to-date!
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Package gutenberg is already up-to-date!
#        | Downloading package ieer to /root/nltk_data...
#        |   Package ieer is already up-to-date!
#        | Downloading package inaugural to /root/nltk_data...
#        |   Package inaugural is already up-to-date!
#        | Downloading package indian to /root/nltk_data...
#        |   Package indian is already up-to-date!
#        | Downloading package jeita to /root/nltk_data...
#        |   Package jeita is already up-to-date!
#        | Downloading package kimmo to /root/nltk_data...
#        |   Package kimmo is already up-to-date!
#        | Downloading package knbc to /root/nltk_data...
#        |   Package knbc is already up-to-date!
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Package lin_thesaurus is already up-to-date!
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Package mac_morpho is already up-to-date!
#        | Downloading package machado to /root/nltk_data...
#        |   Package machado is already up-to-date!
#        | Downloading package masc_tagged to /root/nltk_data...
#        |   Package masc_tagged is already up-to-date!
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Package moses_sample is already up-to-date!
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Package movie_reviews is already up-to-date!
#        | Downloading package names to /root/nltk_data...
#        |   Package names is already up-to-date!
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        |   Package nombank.1.0 is already up-to-date!
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Package nps_chat is already up-to-date!
#        | Downloading package omw to /root/nltk_data...
#        |   Package omw is already up-to-date!
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Package opinion_lexicon is already up-to-date!
#        | Downloading package paradigms to /root/nltk_data...
#        |   Package paradigms is already up-to-date!
#        | Downloading package pil to /root/nltk_data...
#        |   Package pil is already up-to-date!
#        | Downloading package pl196x to /root/nltk_data...
#        |   Package pl196x is already up-to-date!
#        | Downloading package ppattach to /root/nltk_data...
#        |   Package ppattach is already up-to-date!
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Package problem_reports is already up-to-date!
#        | Downloading package propbank to /root/nltk_data...
#        |   Package propbank is already up-to-date!
#        | Downloading package ptb to /root/nltk_data...
#        |   Package ptb is already up-to-date!
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Package product_reviews_1 is already up-to-date!
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Package product_reviews_2 is already up-to-date!
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Package pros_cons is already up-to-date!
#        | Downloading package qc to /root/nltk_data...
#        |   Package qc is already up-to-date!
#        | Downloading package reuters to /root/nltk_data...
#        |   Package reuters is already up-to-date!
#        | Downloading package rte to /root/nltk_data...
#        |   Package rte is already up-to-date!
#        | Downloading package semcor to /root/nltk_data...
#        |   Package semcor is already up-to-date!
#        | Downloading package senseval to /root/nltk_data...
#        |   Package senseval is already up-to-date!
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Package sentiwordnet is already up-to-date!
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Package sentence_polarity is already up-to-date!
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Package shakespeare is already up-to-date!
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Package sinica_treebank is already up-to-date!
#        | Downloading package smultron to /root/nltk_data...
#        |   Package smultron is already up-to-date!
#        | Downloading package state_union to /root/nltk_data...
#        |   Package state_union is already up-to-date!
#        | Downloading package stopwords to /root/nltk_data...
#        |   Package stopwords is already up-to-date!
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Package subjectivity is already up-to-date!
#        | Downloading package swadesh to /root/nltk_data...
#        |   Package swadesh is already up-to-date!
#        | Downloading package switchboard to /root/nltk_data...
#        |   Package switchboard is already up-to-date!
#        | Downloading package timit to /root/nltk_data...
#        |   Package timit is already up-to-date!
#        | Downloading package toolbox to /root/nltk_data...
#        |   Package toolbox is already up-to-date!
#        | Downloading package treebank to /root/nltk_data...
#        |   Package treebank is already up-to-date!
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Package twitter_samples is already up-to-date!
#        | Downloading package udhr to /root/nltk_data...
#        |   Package udhr is already up-to-date!
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Package udhr2 is already up-to-date!
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Package unicode_samples is already up-to-date!
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        |   Package universal_treebanks_v20 is already up-to-date!
#        | Downloading package verbnet to /root/nltk_data...
#        |   Package verbnet is already up-to-date!
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Package verbnet3 is already up-to-date!
#        | Downloading package webtext to /root/nltk_data...
#        |   Package webtext is already up-to-date!
#        | Downloading package wordnet to /root/nltk_data...
#        |   Package wordnet is already up-to-date!
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Package wordnet_ic is already up-to-date!
#        | Downloading package words to /root/nltk_data...
#        |   Package words is already up-to-date!
#        | Downloading package ycoe to /root/nltk_data...
#        |   Package ycoe is already up-to-date!
#        | Downloading package rslp to /root/nltk_data...
#        |   Package rslp is already up-to-date!
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Package maxent_treebank_pos_tagger is already up-to-date!
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Package universal_tagset is already up-to-date!
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Package maxent_ne_chunker is already up-to-date!
#        | Downloading package punkt to /root/nltk_data...
#        |   Package punkt is already up-to-date!
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Package book_grammars is already up-to-date!
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Package sample_grammars is already up-to-date!
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Package spanish_grammars is already up-to-date!
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Package basque_grammars is already up-to-date!
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Package large_grammars is already up-to-date!
#        | Downloading package tagsets to /root/nltk_data...
#        |   Package tagsets is already up-to-date!
#        | Downloading package snowball_data to /root/nltk_data...
#        |   Package snowball_data is already up-to-date!
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Package bllip_wsj_no_aux is already up-to-date!
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Package word2vec_sample is already up-to-date!
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        |   Package panlex_swadesh is already up-to-date!
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Package mte_teip5 is already up-to-date!
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Package averaged_perceptron_tagger is already up-to-date!
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Package averaged_perceptron_tagger_ru is already up-to-
#        |       date!
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Package perluniprops is already up-to-date!
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Package nonbreaking_prefixes is already up-to-date!
#        | Downloading package vader_lexicon to /root/nltk_data...
#        |   Package vader_lexicon is already up-to-date!
#        | Downloading package porter_test to /root/nltk_data...
#        |   Package porter_test is already up-to-date!
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Package wmt15_eval is already up-to-date!
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Package mwa_ppdb is already up-to-date!
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# #**Data** **Cleaning**

# %% [markdown]
# **Converting to Lower Case**

# %%
df['Lower Case'] = df['Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %% [markdown]
# **Removal of Punctuation**

# %%
df['Removal of Punctuation'] = df['Lower Case'].str.replace('[^\w\s]','')

# %% [markdown]
# **Removal of Special Characters**

# %%
import re
df['Removal of Special Characters'] = df['Removal of Punctuation'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))

# %% [markdown]
# **Removal of Stop Words**

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['Stopwords Removal'] = df['Removal of Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %% [markdown]
# **Spelling Correction**

# %%
from textblob import TextBlob
df['Spelling Correction'] = df['Stopwords Removal'].apply(lambda x: str(TextBlob(x).correct()))

# %% [markdown]
# **Tokenization**

# %%
import nltk
nltk.download('punkt')
df['Tokenization'] = df['Spelling Correction'].apply(lambda x: TextBlob(x).words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **Stemming**

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['After Stemming'] = df['Tokenization'].apply(lambda x: " ".join([st.stem(word) for word in x]))

# %% [markdown]
# **Lemmatization**

# %%
from textblob import Word
import nltk
nltk.download('wordnet')

df['After Lemmatization'] = df['After Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df.to_csv('/content/sample_data/reviwes.csv',index=False)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# **1.1 Trigrams**

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

words_sentence = []
for sentence in df['After Lemmatization']:
  words_sentence.append(word_tokenize(sentence))
aftercleaning = [x for x in words_sentence if x != []]
iterations = list(itertools.chain.from_iterable(aftercleaning))

# %%
tri_grams = nltk.trigrams(iterations)
frequency_dist = nltk.FreqDist(tri_grams)
frequency_dist
# Out:
# FreqDist({('everi', 'movi', 'come'): 1,
#           ('movi', 'come', 'truli'): 1,
#           ('come', 'truli', 'make'): 1,
#           ('truli', 'make', 'impact'): 1,
#           ('make', 'impact', 'joaquin'): 1,
#           ('impact', 'joaquin', 'perform'): 1,
#           ('joaquin', 'perform', 'scenographi'): 1,
#           ('perform', 'scenographi', 'brillianc'): 1,
#           ('scenographi', 'brillianc', 'grotesqu'): 1,
#           ('brillianc', 'grotesqu', 'hunt'): 1,
#           ('grotesqu', 'hunt', 'cring'): 1,
#           ('hunt', 'cring', 'hard'): 1,
#           ('cring', 'hard', 'watch'): 1,
#           ('hard', 'watch', 'time'): 1,
#           ('watch', 'time', 'mesmer'): 1,
#           ('time', 'mesmer', 'wont'): 1,
#           ('mesmer', 'wont', 'blink'): 1,
#           ('wont', 'blink', 'eye'): 1,
#           ('blink', 'eye', 'watch'): 1,
#           ('eye', 'watch', 'tragic'): 1,
#           ('watch', 'tragic', 'serious'): 1,
#           ('tragic', 'serious', 'funni'): 1,
#           ('serious', 'funni', 'moment'): 1,
#           ('funni', 'moment', 'emot'): 1,
#           ('moment', 'emot', 'rollercoast'): 1,
#           ('emot', 'rollercoast', 'sometim'): 1,
#           ('rollercoast', 'sometim', 'multipl'): 1,
#           ('sometim', 'multipl', 'emot'): 1,
#           ('multipl', 'emot', 'pop'): 1,
#           ('emot', 'pop', 'time'): 1,
#           ('pop', 'time', 'far'): 1,
#           ('time', 'far', 'typic'): 1,
#           ('far', 'typic', 'actionriddl'): 1,
#           ('typic', 'actionriddl', 'predict'): 1,
#           ('actionriddl', 'predict', 'superhero'): 1,
#           ('predict', 'superhero', 'movi'): 1,
#           ('superhero', 'movi', 'proper'): 1,
#           ('movi', 'proper', 'psycholog'): 1,
#           ('proper', 'psycholog', 'thrillerdrama'): 1,
#           ('psycholog', 'thrillerdrama', 'singl'): 1,
#           ('thrillerdrama', 'singl', 'best'): 1,
#           ('singl', 'best', 'charact'): 1,
#           ('best', 'charact', 'develop'): 1,
#           ('charact', 'develop', 'ever'): 1,
#           ('develop', 'ever', 'seen'): 1,
#           ('ever', 'seen', 'movi'): 2,
#           ('seen', 'movi', 'felt'): 1,
#           ('movi', 'felt', 'alon'): 1,
#           ('felt', 'alon', 'isol'): 1,
#           ('alon', 'isol', 'truli'): 1,
#           ('isol', 'truli', 'relat'): 1,
#           ('truli', 'relat', 'understand'): 1,
#           ('relat', 'understand', 'motiv'): 1,
#           ('understand', 'motiv', 'feel'): 1,
#           ('motiv', 'feel', 'sorri'): 1,
#           ('feel', 'sorri', 'charact'): 1,
#           ('sorri', 'charact', 'lot'): 1,
#           ('charact', 'lot', 'peopl'): 1,
#           ('lot', 'peopl', 'see'): 1,
#           ('peopl', 'see', 'movi'): 1,
#           ('see', 'movi', 'think'): 1,
#           ('movi', 'think', 'encourag'): 1,
#           ('think', 'encourag', 'violenc'): 1,
#           ('encourag', 'violenc', 'truli'): 1,
#           ('violenc', 'truli', 'movi'): 1,
#           ('truli', 'movi', 'encourag'): 1,
#           ('movi', 'encourag', 'everi'): 1,
#           ('encourag', 'everi', 'one'): 1,
#           ('everi', 'one', 'u'): 1,
#           ('one', 'u', 'becom'): 1,
#           ('u', 'becom', 'better'): 1,
#           ('becom', 'better', 'person'): 1,
#           ('better', 'person', 'treat'): 1,
#           ('person', 'treat', 'everyon'): 1,
#           ('treat', 'everyon', 'respect'): 1,
#           ('everyon', 'respect', 'make'): 1,
#           ('respect', 'make', 'feel'): 1,
#           ('make', 'feel', 'like'): 1,
#           ('feel', 'like', 'belong'): 1,
#           ('like', 'belong', 'world'): 1,
#           ('belong', 'world', 'instead'): 1,
#           ('world', 'instead', 'make'): 1,
#           ('instead', 'make', 'feel'): 1,
#           ('make', 'feel', 'isol'): 1,
#           ('feel', 'isol', 'truli'): 1,
#           ('isol', 'truli', 'masterpiec'): 1,
#           ('truli', 'masterpiec', 'best'): 1,
#           ('masterpiec', 'best', 'hollywood'): 1,
#           ('best', 'hollywood', 'film'): 1,
#           ('hollywood', 'film', '2019'): 1,
#           ('film', '2019', 'one'): 1,
#           ('2019', 'one', 'best'): 1,
#           ('one', 'best', 'film'): 2,
#           ('best', 'film', 'decad'): 2,
#           ('film', 'decad', 'truli'): 1,
#           ('decad', 'truli', 'best'): 1,
#           ('truli', 'best', 'film'): 1,
#           ('best', 'film', 'bring'): 1,
#           ('film', 'bring', 'comic'): 1,
#           ('bring', 'comic', 'book'): 1,
#           ('comic', 'book', 'willingli'): 1,
#           ('book', 'willingli', 'realist'): 1,
#           ('willingli', 'realist', 'real'): 1,
#           ('realist', 'real', 'if'): 1,
#           ('real', 'if', 'remark'): 1,
#           ('if', 'remark', 'direct'): 1,
#           ('remark', 'direct', 'cinematographi'): 1,
#           ('direct', 'cinematographi', 'music'): 1,
#           ('cinematographi', 'music', 'act'): 1,
#           ('music', 'act', 'peopl'): 1,
#           ('act', 'peopl', 'surpris'): 1,
#           ('peopl', 'surpris', 'find'): 1,
#           ('surpris', 'find', 'disturb'): 1,
#           ('find', 'disturb', 'violent'): 1,
#           ('disturb', 'violent', 'necess'): 1,
#           ('violent', 'necess', 'messag'): 1,
#           ('necess', 'messag', 'societi'): 1,
#           ('messag', 'societi', 'reflect'): 1,
#           ('societi', 'reflect', 'underappreciatedunrecognizedbulli'): 1,
#           ('reflect', 'underappreciatedunrecognizedbulli', 'peopl'): 1,
#           ('underappreciatedunrecognizedbulli', 'peopl', 'prove'): 1,
#           ('peopl', 'prove', 'someth'): 1,
#           ('prove', 'someth', 'way'): 1,
#           ('someth', 'way', 'show'): 1,
#           ('way', 'show', 'class'): 1,
#           ('show', 'class', 'differ'): 1,
#           ('class', 'differ', 'corrupt'): 1,
#           ('differ', 'corrupt', 'rich'): 1,
#           ('corrupt', 'rich', 'talent'): 1,
#           ('rich', 'talent', 'rule'): 1,
#           ('talent', 'rule', 'other'): 1,
#           ('rule', 'other', 'around'): 1,
#           ('other', 'around', 'exagger'): 1,
#           ('around', 'exagger', 'that'): 1,
#           ('exagger', 'that', 'make'): 1,
#           ('that', 'make', 'differ'): 1,
#           ('make', 'differ', 'believ'): 1,
#           ('differ', 'believ', 'could'): 1,
#           ('believ', 'could', 'multipl'): 1,
#           ('could', 'multipl', 'joke'): 1,
#           ('multipl', 'joke', 'live'): 1,
#           ('joke', 'live', 'societi'): 1,
#           ('live', 'societi', 'could'): 1,
#           ('societi', 'could', 'shake'): 1,
#           ('could', 'shake', 'around'): 1,
#           ('shake', 'around', 'much'): 1,
#           ('around', 'much', 'bitter'): 1,
#           ('much', 'bitter', 'way'): 1,
#           ('bitter', 'way', 'film'): 1,
#           ('way', 'film', 'show'): 1,
#           ('film', 'show', 'make'): 1,
#           ('show', 'make', 'peopl'): 1,
#           ('make', 'peopl', 'comfort'): 1,
#           ('peopl', 'comfort', 'peopl'): 1,
#           ('comfort', 'peopl', 'consid'): 1,
#           ('peopl', 'consid', 'wake'): 1,
#           ('consid', 'wake', 'call'): 1,
#           ('wake', 'call', 'messag'): 1,
#           ('call', 'messag', 'first'): 1,
#           ('messag', 'first', 'film'): 1,
#           ('first', 'film', 'perfect'): 1,
#           ('film', 'perfect', 'film'): 1,
#           ('perfect', 'film', 'joaquin'): 1,
#           ('film', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'give'): 2,
#           ('phoenix', 'give', 'tour'): 1,
#           ('give', 'tour', 'de'): 1,
#           ('tour', 'de', 'forc'): 1,
#           ('de', 'forc', 'perform'): 1,
#           ('forc', 'perform', 'fearless'): 1,
#           ('perform', 'fearless', 'stun'): 1,
#           ('fearless', 'stun', 'emot'): 1,
#           ('stun', 'emot', 'depth'): 1,
#           ('emot', 'depth', 'physic'): 1,
#           ('depth', 'physic', 'imposs'): 1,
#           ('physic', 'imposs', 'talk'): 1,
#           ('imposs', 'talk', 'without'): 1,
#           ('talk', 'without', 'referenc'): 1,
#           ('without', 'referenc', 'heath'): 1,
#           ('referenc', 'heath', 'ledger'): 1,
#           ('heath', 'ledger', 'oscarwin'): 1,
#           ('ledger', 'oscarwin', 'perform'): 1,
#           ('oscarwin', 'perform', 'dark'): 1,
#           ('perform', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'wide'): 1,
#           ('knight', 'wide', 'consid'): 1,
#           ('wide', 'consid', 'definit'): 1,
#           ('consid', 'definit', 'liveact'): 1,
#           ('definit', 'liveact', 'portray'): 1,
#           ('liveact', 'portray', 'joke'): 1,
#           ('portray', 'joke', 'let'): 1,
#           ('joke', 'let', 'talk'): 1,
#           ('let', 'talk', 'fact'): 1,
#           ('talk', 'fact', 'everyon'): 1,
#           ('fact', 'everyon', 'go'): 1,
#           ('everyon', 'go', 'stun'): 1,
#           ('go', 'stun', 'phoenix'): 1,
#           ('stun', 'phoenix', 'accomplish'): 1,
#           ('phoenix', 'accomplish', 'mani'): 1,
#           ('accomplish', 'mani', 'thought'): 1,
#           ('mani', 'thought', 'imposs'): 1,
#           ('thought', 'imposs', 'portray'): 1,
#           ('imposs', 'portray', 'match'): 1,
#           ('portray', 'match', 'potenti'): 1,
#           ('match', 'potenti', 'exce'): 1,
#           ('potenti', 'exce', 'dark'): 1,
#           ('exce', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'clown'): 1,
#           ('knight', 'clown', 'princ'): 1,
#           ('clown', 'princ', 'crime'): 3,
#           ('princ', 'crime', 'time'): 1,
#           ('crime', 'time', 'move'): 1,
#           ('time', 'move', 'anticip'): 1,
#           ('move', 'anticip', 'like'): 1,
#           ('anticip', 'like', 'end'): 1,
#           ('like', 'end', 'fall'): 1,
#           ('end', 'fall', 'short'): 1,
#           ('fall', 'short', 'way'): 1,
#           ('short', 'way', 'short'): 1,
#           ('way', 'short', 'joke'): 1,
#           ('short', 'joke', 'first'): 1,
#           ('joke', 'first', 'time'): 2,
#           ('first', 'time', 'happi'): 1,
#           ('time', 'happi', 'hope'): 1,
#           ('happi', 'hope', 'plea'): 1,
#           ('hope', 'plea', 'ignor'): 1,
#           ('plea', 'ignor', 'complaint'): 1,
#           ('ignor', 'complaint', 'pernici'): 1,
#           ('complaint', 'pernici', 'violenc'): 1,
#           ('pernici', 'violenc', 'embarrass'): 1,
#           ('violenc', 'embarrass', 'say'): 1,
#           ('embarrass', 'say', 'least'): 1,
#           ('say', 'least', 'haven'): 1,
#           ('least', 'haven', 'seen'): 1,
#           ('haven', 'seen', 'comic'): 1,
#           ('seen', 'comic', 'movi'): 1,
#           ('comic', 'movi', 'real'): 1,
#           ('movi', 'real', 'ever'): 1,
#           ('real', 'ever', 'deserv'): 1,
#           ('ever', 'deserv', 'better'): 1,
#           ('deserv', 'better', 'class'): 1,
#           ('better', 'class', 'crimin'): 1,
#           ('class', 'crimin', 'phillip'): 1,
#           ('crimin', 'phillip', 'phoenix'): 1,
#           ('phillip', 'phoenix', 'deliv'): 1,
#           ('phoenix', 'deliv', 'dark'): 1,
#           ('deliv', 'dark', 'joke'): 1,
#           ('dark', 'joke', 'dark'): 1,
#           ('joke', 'dark', 'fall'): 1,
#           ('dark', 'fall', 'love'): 1,
#           ('fall', 'love', 'villain'): 1,
#           ('love', 'villain', 'bad'): 1,
#           ('villain', 'bad', 'gun'): 1,
#           ('bad', 'gun', 'alway'): 1,
#           ('gun', 'alway', 'romant'): 1,
#           ('alway', 'romant', 'anyway'): 1,
#           ('romant', 'anyway', 'let'): 1,
#           ('anyway', 'let', 'start'): 1,
#           ('let', 'start', 'say'): 1,
#           ('start', 'say', 'joaquin'): 1,
#           ('say', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'doesn'): 2,
#           ('phoenix', 'doesn', 'get'): 1,
#           ('doesn', 'get', 'oscar'): 1,
#           ('get', 'oscar', 'movi'): 1,
#           ('oscar', 'movi', 'scar'): 1,
#           ('movi', 'scar', 'cancel'): 1,
#           ('scar', 'cancel', 'phoenix'): 1,
#           ('cancel', 'phoenix', 'amaz'): 1,
#           ('phoenix', 'amaz', 'might'): 1,
#           ('amaz', 'might', 'heard'): 1,
#           ('might', 'heard', 'everi'): 1,
#           ('heard', 'everi', 'review'): 1,
#           ('everi', 'review', 'ever'): 1,
#           ('review', 'ever', 'told'): 1,
#           ('ever', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'best'): 1,
#           ('phillip', 'best', 'stori'): 1,
#           ('best', 'stori', 'line'): 1,
#           ('stori', 'line', 'take'): 1,
#           ('line', 'take', 'visual'): 1,
#           ('take', 'visual', 'breathtak'): 1,
#           ('visual', 'breathtak', 'score'): 1,
#           ('breathtak', 'score', 'org'): 1,
#           ('score', 'org', 'score'): 1,
#           ('org', 'score', 'everi'): 1,
#           ('score', 'everi', 'time'): 1,
#           ('everi', 'time', 'score'): 1,
#           ('time', 'score', 'came'): 1,
#           ('score', 'came', 'felt'): 1,
#           ('came', 'felt', 'uncomfort'): 1,
#           ('felt', 'uncomfort', 'like'): 1,
#           ('uncomfort', 'like', 'someth'): 1,
#           ('like', 'someth', 'horribl'): 1,
#           ('someth', 'horribl', 'happen'): 1,
#           ('horribl', 'happen', 'great'): 1,
#           ('happen', 'great', 'inspir'): 1,
#           ('great', 'inspir', 'taxi'): 1,
#           ('inspir', 'taxi', 'driver'): 2,
#           ('taxi', 'driver', 'king'): 3,
#           ('driver', 'king', 'comedi'): 3,
#           ('king', 'comedi', 'add'): 1,
#           ('comedi', 'add', 'much'): 1,
#           ('add', 'much', 'movi'): 1,
#           ('much', 'movi', 'got'): 1,
#           ('movi', 'got', 'honest'): 1,
#           ('got', 'honest', 'scene'): 1,
#           ('honest', 'scene', 'violent'): 1,
#           ('scene', 'violent', 'disturb'): 1,
#           ('violent', 'disturb', 'honestli'): 1,
#           ('disturb', 'honestli', 'expect'): 1,
#           ('honestli', 'expect', 'wayyyi'): 1,
#           ('expect', 'wayyyi', 'violent'): 1,
#           ('wayyyi', 'violent', 'controversi'): 1,
#           ('violent', 'controversi', 'go'): 1,
#           ('controversi', 'go', 'overal'): 1,
#           ('go', 'overal', 'movi'): 1,
#           ('overal', 'movi', 'great'): 1,
#           ('movi', 'great', 'come'): 1,
#           ('great', 'come', 'oscar'): 1,
#           ('come', 'oscar', 'season'): 1,
#           ('oscar', 'season', 'need'): 1,
#           ('season', 'need', 'nomin'): 1,
#           ('need', 'nomin', 'best'): 1,
#           ('nomin', 'best', 'pictur'): 1,
#           ('best', 'pictur', 'screenplay'): 1,
#           ('pictur', 'screenplay', 'cinematographi'): 1,
#           ('screenplay', 'cinematographi', 'actor'): 1,
#           ('cinematographi', 'actor', 'score'): 1,
#           ('actor', 'score', 'director'): 1,
#           ('score', 'director', 'get'): 1,
#           ('director', 'get', 'peopl'): 1,
#           ('get', 'peopl', 'hate'): 1,
#           ('peopl', 'hate', 'polit'): 1,
#           ('hate', 'polit', 'messag'): 1,
#           ('polit', 'messag', 'peopl'): 1,
#           ('messag', 'peopl', 'think'): 1,
#           ('peopl', 'think', 'need'): 1,
#           ('think', 'need', 'get'): 1,
#           ('need', 'get', 'empti'): 1,
#           ('get', 'empti', 'arthur'): 1,
#           ('empti', 'arthur', 'mad'): 1,
#           ('arthur', 'mad', 'come'): 1,
#           ('mad', 'come', 'point'): 1,
#           ('come', 'point', 'never'): 1,
#           ('point', 'never', 'enjoy'): 1,
#           ('never', 'enjoy', 'masterpiec'): 1,
#           ('enjoy', 'masterpiec', 'joaquin'): 1,
#           ('masterpiec', 'joaquin', 'phoenix'): 2,
#           ('joaquin', 'phoenix', 'told'): 1,
#           ('phoenix', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'overdid'): 1,
#           ('phillip', 'overdid', 'movi'): 1,
#           ('overdid', 'movi', 'actingmus'): 1,
#           ('movi', 'actingmus', 'cinematographi'): 1,
#           ('actingmus', 'cinematographi', 'amaz'): 1,
#           ('cinematographi', 'amaz', 'plea'): 1,
#           ('amaz', 'plea', 'enjoy'): 1,
#           ('plea', 'enjoy', 'movi'): 1,
#           ('enjoy', 'movi', 'without'): 1,
#           ('movi', 'without', 'overthink'): 1,
#           ('without', 'overthink', 'seen'): 1,
#           ('overthink', 'seen', 'joke'): 1,
#           ('seen', 'joke', 'yesterday'): 1,
#           ('joke', 'yesterday', 'venic'): 1,
#           ('yesterday', 'venic', 'earli'): 1,
#           ('venic', 'earli', 'inflat'): 1,
#           ('earli', 'inflat', 'screen'): 1,
#           ('inflat', 'screen', 'troubl'): 1,
#           ('screen', 'troubl', 'audit'): 1,
#           ('troubl', 'audit', 'lead'): 1,
#           ('audit', 'lead', 'nearhour'): 1,
#           ('lead', 'nearhour', 'delay'): 1,
#           ('nearhour', 'delay', 'definit'): 1,
#           ('delay', 'definit', 'worth'): 1,
#           ('definit', 'worth', 'joke'): 1,
#           ('worth', 'joke', 'deserv'): 1,
#           ('joke', 'deserv', 'present'): 1,
#           ('deserv', 'present', 'venic'): 1,
#           ('present', 'venic', 'film'): 1,
#           ('venic', 'film', 'festiv'): 1,
#           ('film', 'festiv', 'event'): 1,
#           ('festiv', 'event', 'regard'): 1,
#           ('event', 'regard', 'cinema'): 1,
#           ('regard', 'cinema', 'form'): 1,
#           ('cinema', 'form', 'art'): 1,
#           ('form', 'art', 'film'): 1,
#           ('art', 'film', 'far'): 1,
#           ('film', 'far', 'blockbust'): 1,
#           ('far', 'blockbust', 'mere'): 1,
#           ('blockbust', 'mere', 'entertain'): 1,
#           ('mere', 'entertain', 'movi'): 1,
#           ('entertain', 'movi', 'film'): 1,
#           ('movi', 'film', 'gene'): 1,
#           ('film', 'gene', 'focus'): 1,
#           ('gene', 'focus', 'psychic'): 1,
#           ('focus', 'psychic', 'main'): 1,
#           ('psychic', 'main', 'charact'): 1,
#           ('main', 'charact', 'slowli'): 1,
#           ('charact', 'slowli', 'crumbl'): 1,
#           ('slowli', 'crumbl', 'pressur'): 1,
#           ('crumbl', 'pressur', 'societi'): 1,
#           ('pressur', 'societi', 'thu'): 1,
#           ('societi', 'thu', 'joaquin'): 1,
#           ('thu', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'wonder'): 1,
#           ('phoenix', 'wonder', 'perform'): 1,
#           ('wonder', 'perform', 'earn'): 1,
#           ('perform', 'earn', 'almost'): 1,
#           ('earn', 'almost', 'sure'): 1,
#           ('almost', 'sure', 'nomin'): 1,
#           ('sure', 'nomin', 'scar'): 1,
#           ('nomin', 'scar', 'least'): 1,
#           ('scar', 'least', 'take'): 1,
#           ('least', 'take', 'joke'): 1,
#           ('take', 'joke', 'differ'): 1,
#           ('joke', 'differ', 'ledger'): 1,
#           ('differ', 'ledger', 'id'): 1,
#           ('ledger', 'id', 'say'): 1,
#           ('id', 'say', 'equal'): 1,
#           ('say', 'equal', 'good'): 1,
#           ('equal', 'good', 'main'): 1,
#           ('good', 'main', 'differ'): 1,
#           ('main', 'differ', 'might'): 1,
#           ('differ', 'might', 'ledger'): 1,
#           ('might', 'ledger', 'joke'): 1,
#           ('ledger', 'joke', 'ration'): 1,
#           ('joke', 'ration', 'act'): 1,
#           ('ration', 'act', 'insan'): 1,
#           ('act', 'insan', 'phoenix'): 1,
#           ('insan', 'phoenix', 'insan'): 1,
#           ('phoenix', 'insan', 'root'): 1,
#           ('insan', 'root', 'despit'): 1,
#           ('root', 'despit', 'movi'): 1,
#           ('despit', 'movi', 'superhero'): 1,
#           ('movi', 'superhero', 'villain'): 1,
#           ('superhero', 'villain', 'joke'): 1,
#           ('villain', 'joke', 'much'): 1,
#           ('joke', 'much', 'superior'): 1,
#           ('much', 'superior', 'move'): 1,
#           ('superior', 'move', 'gene'): 1,
#           ('move', 'gene', 'id'): 1,
#           ('gene', 'id', 'exclud'): 1,
#           ('id', 'exclud', 'dark'): 1,
#           ('exclud', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'trilog'): 2,
#           ('knight', 'trilog', 'joke'): 1,
#           ('trilog', 'joke', 'easili'): 1,
#           ('joke', 'easili', 'good'): 1,
#           ('easili', 'good', 'plan'): 1,
#           ('good', 'plan', 'move'): 1,
#           ('plan', 'move', 'least'): 1,
#           ('move', 'least', 'close'): 1,
#           ('least', 'close', 'smallscal'): 1,
#           ('close', 'smallscal', 'film'): 1,
#           ('smallscal', 'film', 'distinct'): 1,
#           ('film', 'distinct', 'style'): 1,
#           ('distinct', 'style', 'cinematographi'): 1,
#           ('style', 'cinematographi', 'can'): 1,
#           ('cinematographi', 'can', 'not'): 1,
#           ('can', 'not', 'appreci'): 1,
#           ('not', 'appreci', 'set'): 1,
#           ('appreci', 'set', 'cinephil'): 1,
#           ('set', 'cinephil', 'refer'): 1,
#           ('cinephil', 'refer', 'howev'): 1,
#           ('refer', 'howev', 'feel'): 1,
#           ('howev', 'feel', 'forc'): 1,
#           ('feel', 'forc', 'overlay'): 1,
#           ('forc', 'overlay', 'oppress'): 1,
#           ('overlay', 'oppress', 'notabl'): 1,
#           ('oppress', 'notabl', 'similar'): 1,
#           ('notabl', 'similar', 'scorses'): 1,
#           ('similar', 'scorses', 'taxi'): 1,
#           ('scorses', 'taxi', 'driver'): 1,
#           ('king', 'comedi', 'also'): 1,
#           ('comedi', 'also', 'chain'): 1,
#           ('also', 'chain', 'modern'): 1,
#           ('chain', 'modern', 'time'): 1,
#           ('modern', 'time', 'somewhat'): 1,
#           ('time', 'somewhat', 'refer'): 1,
#           ('somewhat', 'refer', 'eager'): 1,
#           ('refer', 'eager', 'see'): 1,
#           ('eager', 'see', 'noncomed'): 1,
#           ('see', 'noncomed', 'effort'): 1,
#           ('noncomed', 'effort', 'told'): 1,
#           ('effort', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'movi'): 1,
#           ('phillip', 'movi', 'far'): 1,
#           ('movi', 'far', 'probabl'): 1,
#           ('far', 'probabl', 'best'): 1,
#           ('probabl', 'best', '2019'): 1,
#           ('best', '2019', 'worst'): 1,
#           ('2019', 'worst', 'contest'): 1,
#           ('worst', 'contest', 'far'): 1,
#           ('contest', 'far', 'door'): 1,
#           ('far', 'door', 'gloria'): 1,
#           ('door', 'gloria', 'upon'): 1,
#           ('gloria', 'upon', 'time'): 1,
#           ('upon', 'time', 'hollywood'): 2,
#           ('time', 'hollywood', 'convinc'): 1,
#           ('hollywood', 'convinc', 'sad'): 1,
#           ('convinc', 'sad', 'joaquin'): 1,
#           ('sad', 'joaquin', 'miss'): 1,
#           ('joaquin', 'miss', 'oscar'): 1,
#           ('miss', 'oscar', 'gladiat'): 1,
#           ('oscar', 'gladiat', 'compel'): 1,
#           ('gladiat', 'compel', 'villain'): 1,
#           ('compel', 'villain', 'quit'): 1,
#           ('villain', 'quit', 'confid'): 1,
#           ('quit', 'confid', 'win'): 1,
#           ('confid', 'win', 'joke'): 1,
#           ('win', 'joke', 'damn'): 1,
#           ('joke', 'damn', 'movi'): 1,
#           ('damn', 'movi', 'keep'): 1,
#           ('movi', 'keep', 'u'): 1,
#           ('keep', 'u', 'toe'): 1,
#           ('u', 'toe', 'time'): 1,
#           ('toe', 'time', 'predict'): 1,
#           ('time', 'predict', 'storylin'): 1,
#           ('predict', 'storylin', 'realli'): 1,
#           ('storylin', 'realli', 'deep'): 1,
#           ('realli', 'deep', 'interest'): 1,
#           ('deep', 'interest', 'plot'): 1,
#           ('interest', 'plot', 'forget'): 1,
#           ('plot', 'forget', 'mention'): 1,
#           ('forget', 'mention', 'act'): 1,
#           ('mention', 'act', 'damn'): 1,
#           ('act', 'damn', 'no'): 1,
#           ('damn', 'no', 'joaquin'): 1,
#           ('no', 'joaquin', 'teach'): 1,
#           ('joaquin', 'teach', 'u'): 1,
#           ('teach', 'u', 'realli'): 1,
#           ('u', 'realli', '5'): 1,
#           ('realli', '5', 'star'): 1,
#           ('5', 'star', 'act'): 1,
#           ('star', 'act', 'enjoy'): 1,
#           ('act', 'enjoy', 'movi'): 1,
#           ('enjoy', 'movi', 'get'): 1,
#           ('movi', 'get', 'wine'): 1,
#           ('get', 'wine', 'hand'): 1,
#           ('wine', 'hand', 'close'): 1,
#           ('hand', 'close', 'curtain'): 1,
#           ('close', 'curtain', 'turn'): 1,
#           ('curtain', 'turn', 'or'): 1,
#           ('turn', 'or', 'cellphon'): 1,
#           ('or', 'cellphon', 'put'): 1,
#           ('cellphon', 'put', 'disturb'): 1,
#           ('put', 'disturb', 'sign'): 1,
#           ('disturb', 'sign', 'or'): 1,
#           ('sign', 'or', 'door'): 1,
#           ('or', 'door', 'best'): 1,
#           ('door', 'best', 'dark'): 1,
#           ('best', 'dark', 'thrill'): 1,
#           ('dark', 'thrill', 'suspens'): 1,
#           ('thrill', 'suspens', 'movi'): 1,
#           ('suspens', 'movi', 'get'): 1,
#           ('movi', 'get', 'experi'): 1,
#           ('get', 'experi', 'movi'): 1,
#           ('experi', 'movi', 'caus'): 1,
#           ('movi', 'caus', 'audienc'): 1,
#           ('caus', 'audienc', 'consid'): 1,
#           ('audienc', 'consid', 'mani'): 1,
#           ('consid', 'mani', 'topic'): 1,
#           ('mani', 'topic', 'moral'): 1,
#           ('topic', 'moral', 'particularli'): 1,
#           ('moral', 'particularli', 'poor'): 1,
#           ('particularli', 'poor', 'choic'): 1,
#           ('poor', 'choic', 'made'): 1,
#           ('choic', 'made', 'joke'): 1,
#           ('made', 'joke', 'joke'): 1,
#           ('joke', 'joke', 'reliabl'): 1,
#           ('joke', 'reliabl', 'movi'): 1,
#           ('reliabl', 'movi', 'antagonist'): 1,
#           ('movi', 'antagonist', 'usual'): 1,
#           ('antagonist', 'usual', 'think'): 1,
#           ('usual', 'think', 'give'): 1,
#           ('think', 'give', 'realist'): 1,
#           ('give', 'realist', 'view'): 1,
#           ('realist', 'view', 'bad'): 1,
#           ('view', 'bad', 'peopl'): 1,
#           ('bad', 'peopl', 'usual'): 1,
#           ('peopl', 'usual', '100'): 1,
#           ('usual', '100', 'bad'): 1,
#           ('100', 'bad', 'way'): 1,
#           ('bad', 'way', 'societi'): 1,
#           ('way', 'societi', 'often'): 1,
#           ('societi', 'often', 'judg'): 1,
#           ('often', 'judg', 'import'): 1,
#           ('judg', 'import', 'know'): 1,
#           ('import', 'know', 'sympath'): 1,
#           ('know', 'sympath', 'joke'): 1,
#           ('sympath', 'joke', 'toward'): 1,
#           ('joke', 'toward', 'begin'): 1,
#           ('toward', 'begin', 'movi'): 1,
#           ('begin', 'movi', 'need'): 1,
#           ('movi', 'need', 'identifi'): 1,
#           ('need', 'identifi', 'threat'): 1,
#           ('identifi', 'threat', 'begin'): 1,
#           ('threat', 'begin', 'make'): 1,
#           ('begin', 'make', 'certain'): 1,
#           ('make', 'certain', 'bad'): 1,
#           ('certain', 'bad', 'choic'): 1,
#           ('bad', 'choic', 'movi'): 1,
#           ('choic', 'movi', 'suitabl'): 1,
#           ('movi', 'suitabl', 'adult'): 1,
#           ('suitabl', 'adult', 'will'): 1,
#           ('adult', 'will', 'pick'): 1,
#           ('will', 'pick', 'apart'): 1,
#           ('pick', 'apart', 'think'): 1,
#           ('apart', 'think', 'clinic'): 1,
#           ('think', 'clinic', 'isn'): 1,
#           ('clinic', 'isn', 'light'): 1,
#           ('isn', 'light', 'amus'): 1,
#           ('light', 'amus', 'substanc'): 1,
#           ('amus', 'substanc', 'make'): 1,
#           ('substanc', 'make', 'good'): 1,
#           ('make', 'good', 'agent'): 1,
#           ('good', 'agent', 'abl'): 1,
#           ('agent', 'abl', 'ponder'): 1,
#           ('abl', 'ponder', 'underli'): 1,
#           ('ponder', 'underli', 'theme'): 1,
#           ('underli', 'theme', 'hand'): 1,
#           ('theme', 'hand', 'thought'): 1,
#           ('hand', 'thought', 'isn'): 1,
#           ('thought', 'isn', 'best'): 1,
#           ('isn', 'best', 'movi'): 1,
#           ('best', 'movi', 'movi'): 1,
#           ('movi', 'movi', 'affect'): 1,
#           ('movi', 'affect', 'way'): 1,
#           ('affect', 'way', 'make'): 1,
#           ('way', 'make', 'physic'): 1,
#           ('make', 'physic', 'pain'): 1,
#           ('physic', 'pain', 'experi'): 1,
#           ('pain', 'experi', 'good'): 1,
#           ('experi', 'good', 'way'): 1,
#           ('good', 'way', 'act'): 1,
#           ('way', 'act', 'cinematographi'): 1,
#           ('act', 'cinematographi', 'sound'): 1,
#           ('cinematographi', 'sound', 'design'): 1,
#           ('sound', 'design', 'script'): 1,
#           ('design', 'script', 'phenomenon'): 1,
#           ('script', 'phenomenon', 'movi'): 1,
#           ('phenomenon', 'movi', 'triumph'): 1,
#           ('movi', 'triumph', 'joaquin'): 1,
#           ('triumph', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'deserv'): 2,
#           ('phoenix', 'deserv', 'oscar'): 2,
#           ('deserv', 'oscar', 'win'): 1,
#           ('oscar', 'win', 'th'): 1,
#           ('win', 'th', 'need'): 1,
#           ('th', 'need', 'say'): 1,
#           ('need', 'say', 'everyth'): 1,
#           ('say', 'everyth', 'movi'): 1,
#           ('everyth', 'movi', 'wast'): 1,
#           ('movi', 'wast', 'everi'): 1,
#           ('wast', 'everi', 'singl'): 1,
#           ('everi', 'singl', 'way'): 1,
#           ('singl', 'way', 'joke'): 1,
#           ('way', 'joke', 'isn'): 1,
#           ('joke', 'isn', 'awesom'): 1,
#           ('isn', 'awesom', 'comic'): 1,
#           ('awesom', 'comic', 'book'): 1,
#           ('comic', 'book', 'movi'): 2,
#           ('book', 'movi', 'awesom'): 1,
#           ('movi', 'awesom', 'movi'): 1,
#           ('awesom', 'movi', 'period'): 1,
#           ('movi', 'period', 'offer'): 1,
#           ('period', 'offer', 'easi'): 1,
#           ('offer', 'easi', 'answer'): 1,
#           ('easi', 'answer', 'settl'): 1,
#           ('answer', 'settl', 'question'): 1,
#           ('settl', 'question', 'rais'): 1,
#           ('question', 'rais', 'cruel'): 1,
#           ('rais', 'cruel', 'societi'): 1,
#           ('cruel', 'societi', 'declin'): 1,
#           ('societi', 'declin', 'joaquin'): 1,
#           ('declin', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'fulli'): 1,
#           ('phoenix', 'fulli', 'commit'): 1,
#           ('fulli', 'commit', 'perform'): 1,
#           ('commit', 'perform', 'told'): 1,
#           ('perform', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'wast'): 1,
#           ('phillip', 'wast', 'albeit'): 1,
#           ('wast', 'albeit', 'loo'): 1,
#           ('albeit', 'loo', 'invent'): 1,
#           ('loo', 'invent', 'do'): 1,
#           ('invent', 'do', 'sourc'): 1,
#           ('do', 'sourc', 'materi'): 1,
#           ('sourc', 'materi', 'make'): 1,
#           ('materi', 'make', 'joke'): 1,
#           ('make', 'joke', 'film'): 1,
#           ('joke', 'film', 'leav'): 1,
#           ('film', 'leav', 'comic'): 1,
#           ('leav', 'comic', 'book'): 1,
#           ('comic', 'book', 'fan'): 1,
#           ('book', 'fan', 'nonfan'): 1,
#           ('fan', 'nonfan', 'alik'): 1,
#           ('nonfan', 'alik', 'disturb'): 1,
#           ('alik', 'disturb', 'move'): 1,
#           ('disturb', 'move', 'right'): 1,
#           ('move', 'right', 'way'): 1,
#           ('right', 'way', 'stop'): 1,
#           ('way', 'stop', 'watch'): 1,
#           ('stop', 'watch', 'move'): 1,
#           ('watch', 'move', 'joaquin'): 1,
#           ('move', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'award'): 1,
#           ('phoenix', 'award', 'oscar'): 1,
#           ('award', 'oscar', 'tremend'): 1,
#           ('oscar', 'tremend', 'act'): 1,
#           ('tremend', 'act', 'quit'): 1,
#           ('act', 'quit', 'reli'): 1,
#           ('quit', 'reli', 'critic'): 1,
#           ('reli', 'critic', 'review'): 1,
#           ('critic', 'review', 'year'): 1,
#           ('review', 'year', 'ago'): 1,
#           ('year', 'ago', 'notic'): 1,
#           ('ago', 'notic', 'movi'): 1,
#           ('notic', 'movi', 'critic'): 1,
#           ('movi', 'critic', 'rate'): 1,
#           ('critic', 'rate', 'low'): 1,
#           ('rate', 'low', 'viewer'): 1,
#           ('low', 'viewer', 'rate'): 1,
#           ('viewer', 'rate', 'high'): 1,
#           ('rate', 'high', 'said'): 1,
#           ('high', 'said', 'point'): 1,
#           ('said', 'point', 'critic'): 1,
#           ('point', 'critic', 'movi'): 1,
#           ('critic', 'movi', 'oh'): 1,
#           ('movi', 'oh', 'wrong'): 1,
#           ('oh', 'wrong', 'went'): 1,
#           ('wrong', 'went', 'saw'): 1,
#           ('went', 'saw', 'tone'): 1,
#           ('saw', 'tone', 'mon'): 1,
#           ('tone', 'mon', 'went'): 1,
#           ('mon', 'went', 'skeptic'): 1,
#           ('went', 'skeptic', 'w'): 1,
#           ('skeptic', 'w', 'low'): 1,
#           ('w', 'low', 'expect'): 1,
#           ('low', 'expect', 'knew'): 1,
#           ('expect', 'knew', 'expect'): 1,
#           ('knew', 'expect', 'typic'): 1,
#           ('expect', 'typic', 'super'): 1,
#           ('typic', 'super', 'hero'): 1,
#           ('super', 'hero', 'movi'): 2,
#           ('hero', 'movi', 'got'): 1,
#           ('movi', 'got', 'masterpiec'): 1,
#           ('got', 'masterpiec', 'went'): 1,
#           ('masterpiec', 'went', 'expect'): 1,
#           ('went', 'expect', 'sheer'): 1,
#           ('expect', 'sheer', 'boredom'): 1,
#           ('sheer', 'boredom', 'instead'): 1,
#           ('boredom', 'instead', 'edg'): 1,
#           ('instead', 'edg', 'seat'): 1,
#           ('edg', 'seat', 'whole'): 1,
#           ('seat', 'whole', 'time'): 1,
#           ('whole', 'time', 'action'): 1,
#           ('time', 'action', 'edg'): 1,
#           ('action', 'edg', 'seat'): 1,
#           ('edg', 'seat', 'fear'): 1,
#           ('seat', 'fear', 'may'): 1,
#           ('fear', 'may', 'say'): 1,
#           ('may', 'say', 'next'): 1,
#           ('say', 'next', 'edg'): 1,
#           ('next', 'edg', 'seat'): 1,
#           ('edg', 'seat', 'see'): 1,
#           ('seat', 'see', 'charact'): 1,
#           ('see', 'charact', 'evolv'): 1,
#           ('charact', 'evolv', 'know'): 1,
#           ('evolv', 'know', '1'): 1,
#           ('know', '1', 'villain'): 1,
#           ('1', 'villain', 'batman'): 1,
#           ('villain', 'batman', 'beyond'): 1,
#           ('batman', 'beyond', 'geniu'): 1,
#           ('beyond', 'geniu', 'joaquin'): 1,
#           ('geniu', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'true'): 1,
#           ('phoenix', 'true', 'master'): 1,
#           ('true', 'master', 'perfect'): 1,
#           ('master', 'perfect', 'art'): 1,
#           ('perfect', 'art', 'consum'): 1,
#           ('art', 'consum', 'charact'): 1,
#           ('consum', 'charact', 'may'): 1,
#           ('charact', 'may', 'place'): 1,
#           ('may', 'place', 'dont'): 1,
#           ('place', 'dont', 'care'): 1,
#           ('dont', 'care', 'movi'): 1,
#           ('care', 'movi', 'stori'): 1,
#           ('movi', 'stori', 'act'): 1,
#           ('stori', 'act', 'direct'): 1,
#           ('act', 'direct', 'effect'): 1,
#           ('direct', 'effect', 'everyon'): 1,
#           ('effect', 'everyon', 'brought'): 1,
#           ('everyon', 'brought', 'game'): 1,
#           ('brought', 'game', 'up'): 1,
#           ('game', 'up', 'definit'): 1,
#           ('up', 'definit', 'deserv'): 1,
#           ('definit', 'deserv', 'nod'): 1,
#           ('deserv', 'nod', 'win'): 1,
#           ('nod', 'win', 'role'): 1,
#           ('win', 'role', 'comparison'): 1,
#           ('role', 'comparison', 'jack'): 1,
#           ('comparison', 'jack', 'nicholson'): 1,
#           ('jack', 'nicholson', 'heath'): 3,
#           ('nicholson', 'heath', 'ledger'): 3,
#           ('heath', 'ledger', 'actor'): 1,
#           ('ledger', 'actor', 'took'): 1,
#           ('actor', 'took', 'charact'): 1,
#           ('took', 'charact', 'differ'): 1,
#           ('charact', 'differ', 'level'): 1,
#           ('differ', 'level', 'differ'): 1,
#           ('level', 'differ', 'stori'): 1,
#           ('differ', 'stori', 'point'): 1,
#           ('stori', 'point', 'differ'): 1,
#           ('point', 'differ', 'point'): 1,
#           ('differ', 'point', 'time'): 1,
#           ('point', 'time', 'comparison'): 1,
#           ('time', 'comparison', 'would'): 1,
#           ('comparison', 'would', 'feasibl'): 1,
#           ('would', 'feasibl', 'fair'): 1,
#           ('feasibl', 'fair', 'actor'): 1,
#           ('fair', 'actor', 'embrac'): 1,
#           ('actor', 'embrac', 'made'): 1,
#           ('embrac', 'made', 'come'): 1,
#           ('made', 'come', 'life'): 1,
#           ('come', 'life', 'geniu'): 1,
#           ('life', 'geniu', 'way'): 1,
#           ('geniu', 'way', 'thought'): 1,
#           ('way', 'thought', 'film'): 1,
#           ('thought', 'film', 'good'): 1,
#           ('film', 'good', 'dont'): 1,
#           ('good', 'dont', 'get'): 1,
#           ('dont', 'get', 'hope'): 1,
#           ('get', 'hope', 'person'): 1,
#           ('hope', 'person', 'act'): 1,
#           ('person', 'act', 'amaz'): 1,
#           ('act', 'amaz', 'film'): 1,
#           ('amaz', 'film', 'good'): 1,
#           ('film', 'good', 'overal'): 1,
#           ('good', 'overal', 'think'): 1,
#           ('overal', 'think', 'masterpiec'): 1,
#           ('think', 'masterpiec', 'film'): 1,
#           ('masterpiec', 'film', 'year'): 1,
#           ('film', 'year', 'bit'): 1,
#           ('year', 'bit', 'vers'): 1,
#           ('bit', 'vers', 'throughout'): 1,
#           ('vers', 'throughout', 'review'): 1,
#           ('throughout', 'review', 'way'): 1,
#           ('review', 'way', 'dislik'): 1,
#           ('way', 'dislik', 'film'): 1,
#           ('dislik', 'film', 'thought'): 1,
#           ('film', 'thought', 'realli'): 1,
#           ('thought', 'realli', 'good'): 1,
#           ('realli', 'good', 'overhyp'): 1,
#           ('good', 'overhyp', 'feel'): 1,
#           ('overhyp', 'feel', 'though'): 1,
#           ('feel', 'though', 'lot'): 1,
#           ('though', 'lot', '1010'): 1,
#           ('lot', '1010', 'review'): 1,
#           ('1010', 'review', 'pure'): 1,
#           ('review', 'pure', 'base'): 1,
#           ('pure', 'base', 'fact'): 1,
#           ('base', 'fact', 'alreadi'): 1,
#           ('fact', 'alreadi', 'amaz'): 1,
#           ('alreadi', 'amaz', 'review'): 1,
#           ('amaz', 'review', 'peopl'): 1,
#           ('review', 'peopl', 'want'): 1,
#           ('peopl', 'want', 'carri'): 1,
#           ('want', 'carri', 'prais'): 1,
#           ('carri', 'prais', 'joke'): 1,
#           ('prais', 'joke', 'film'): 1,
#           ('joke', 'film', 'releas'): 1,
#           ('film', 'releas', 'random'): 1,
#           ('releas', 'random', 'guy'): 1,
#           ('random', 'guy', 'situat'): 1,
#           ('guy', 'situat', 'dont'): 1,
#           ('situat', 'dont', 'think'): 1,
#           ('dont', 'think', 'review'): 1,
#           ('think', 'review', 'would'): 1,
#           ('review', 'would', 'high'): 1,
#           ('would', 'high', 'mayb'): 1,
#           ('high', 'mayb', 'that'): 1,
#           ('mayb', 'that', 'point'): 1,
#           ('that', 'point', 'realli'): 1,
#           ('point', 'realli', 'understand'): 1,
#           ('realli', 'understand', 'ten'): 1,
#           ('understand', 'ten', 'sure'): 1,
#           ('ten', 'sure', 'good'): 1,
#           ('sure', 'good', 'movi'): 1,
#           ('good', 'movi', 'good'): 1,
#           ('movi', 'good', 'act'): 1,
#           ('good', 'act', 'nice'): 1,
#           ('act', 'nice', 'shoot'): 1,
#           ('nice', 'shoot', 'plot'): 1,
#           ('shoot', 'plot', 'intrigu'): 1,
#           ('plot', 'intrigu', 'time'): 1,
#           ('intrigu', 'time', 'realli'): 1,
#           ('time', 'realli', 'long'): 1,
#           ('realli', 'long', 'somewhat'): 1,
#           ('long', 'somewhat', 'bore'): 1,
#           ('somewhat', 'bore', 'need'): 1,
#           ('bore', 'need', 'doublecheck'): 1,
#           ('need', 'doublecheck', 'gene'): 1,
#           ('doublecheck', 'gene', 'see'): 1,
#           ('gene', 'see', 'drama'): 1,
#           ('see', 'drama', 'crime'): 1,
#           ('drama', 'crime', 'drama'): 1,
#           ('crime', 'drama', 'thrill'): 1,
#           ('drama', 'thrill', 'said'): 1,
#           ('thrill', 'said', 'would'): 1,
#           ('said', 'would', 'put'): 1,
#           ('would', 'put', 'mayb'): 1,
#           ('put', 'mayb', '90'): 1,
#           ('mayb', '90', 'drama'): 1,
#           ('90', 'drama', 'rest'): 1,
#           ('drama', 'rest', 'thrill'): 1,
#           ('rest', 'thrill', 'miss'): 1,
#           ('thrill', 'miss', 'dialogu'): 1,
#           ('miss', 'dialogu', 'depth'): 1,
#           ('dialogu', 'depth', 'substanc'): 1,
#           ('depth', 'substanc', 'plot'): 1,
#           ('substanc', 'plot', 'realli'): 1,
#           ('plot', 'realli', 'somewhat'): 1,
#           ('realli', 'somewhat', 'crazi'): 1,
#           ('somewhat', 'crazi', 'person'): 1,
#           ('crazi', 'person', 'becom'): 1,
#           ('person', 'becom', 'bit'): 1,
#           ('becom', 'bit', 'brazier'): 1,
#           ('bit', 'brazier', 'sure'): 1,
#           ('brazier', 'sure', 'underton'): 1,
#           ('sure', 'underton', 'societi'): 1,
#           ('underton', 'societi', 'system'): 1,
#           ('societi', 'system', 'mean'): 1,
#           ('system', 'mean', 'charact'): 1,
#           ('mean', 'charact', 'peopl'): 1,
#           ('charact', 'peopl', 'bring'): 1,
#           ('peopl', 'bring', 'creat'): 1,
#           ('bring', 'creat', 'evil'): 1,
#           ('creat', 'evil', 'beast'): 1,
#           ('evil', 'beast', 'later'): 1,
#           ('beast', 'later', 'want'): 1,
#           ('later', 'want', 'destroy'): 1,
#           ('want', 'destroy', 'everyth'): 1,
#           ('destroy', 'everyth', 'absolut'): 1,
#           ('everyth', 'absolut', 'think'): 1,
#           ('absolut', 'think', 'intrigu'): 1,
#           ('think', 'intrigu', 'stori'): 1,
#           ('intrigu', 'stori', 'plot'): 1,
#           ('stori', 'plot', 'dialogu'): 1,
#           ('plot', 'dialogu', 'enough'): 1,
#           ('dialogu', 'enough', 'give'): 1,
#           ('enough', 'give', 'ten'): 1,
#           ('give', 'ten', 'worthi'): 1,
#           ('ten', 'worthi', 'watch'): 1,
#           ('worthi', 'watch', 'ye'): 1,
#           ('watch', 'ye', 'amaz'): 1,
#           ('ye', 'amaz', 'went'): 1,
#           ('amaz', 'went', 'film'): 1,
#           ('went', 'film', 'expect'): 1,
#           ('film', 'expect', 'allie'): 1,
#           ('expect', 'allie', 'classic'): 1,
#           ('allie', 'classic', 'base'): 1,
#           ('classic', 'base', 'review'): 1,
#           ('base', 'review', 'read'): 1,
#           ('review', 'read', 'end'): 1,
#           ('read', 'end', 'watch'): 1,
#           ('end', 'watch', 'decent'): 1,
#           ('watch', 'decent', 'film'): 1,
#           ('decent', 'film', 'overal'): 1,
#           ('film', 'overal', 'phoenix'): 1,
#           ('overal', 'phoenix', 'outstand'): 1,
#           ('phoenix', 'outstand', 'definit'): 1,
#           ('outstand', 'definit', 'part'): 1,
#           ('definit', 'part', 'feel'): 1,
#           ('part', 'feel', 'like'): 1,
#           ('feel', 'like', 'you'): 1,
#           ('like', 'you', 'seen'): 1,
#           ('you', 'seen', 'trailer'): 1,
#           ('seen', 'trailer', 'you'): 1,
#           ('trailer', 'you', 'seen'): 1,
#           ('you', 'seen', 'movi'): 1,
#           ('seen', 'movi', 'best'): 1,
#           ('movi', 'best', 'way'): 1,
#           ('best', 'way', 'describ'): 1,
#           ('way', 'describ', 'film'): 1,
#           ('describ', 'film', 'feel'): 1,
#           ('film', 'feel', 'like'): 1,
#           ('feel', 'like', '2'): 1,
#           ('like', '2', 'hour'): 1,
#           ('2', 'hour', 'version'): 1,
#           ('hour', 'version', 'trailer'): 1,
#           ('version', 'trailer', '2'): 1,
#           ('trailer', '2', 'hour'): 1,
#           ('2', 'hour', 'rel'): 1,
#           ('hour', 'rel', 'common'): 1,
#           ('rel', 'common', 'aunti'): 1,
#           ('common', 'aunti', 'felt'): 1,
#           ('aunti', 'felt', 'lot'): 1,
#           ('felt', 'lot', 'longerwhich'): 1,
#           ...})

# %% [markdown]
# **1.2 Probability of Bi-Grams**

# %%
from collections import Counter
bi_grams = nltk.bigrams(iterations)
frequency_dist = nltk.FreqDist(bi_grams)
bi_grams_dict = dict(frequency_dist)
for word in bi_grams_dict:
  print( str(word) + ':' + str(bi_grams_dict[word] / iterations.count(word[0])))
# Out:
# Streaming output truncated to the last 5000 lines.
# ('long', 'time'):0.45454545454545453
# ('time', 'watch'):0.024390243902439025
# ('watch', 'bore'):0.022222222222222223
# ('bore', 'aesthet'):0.05
# ('aesthet', 'amaz'):1.0
# ('amaz', 'music'):0.07692307692307693
# ('music', 'good'):0.14285714285714285
# ('good', 'stori'):0.05454545454545454
# ('stori', 'execut'):0.05714285714285714
# ('execut', 'me'):0.25
# ('me', 'perform'):1.0
# ('perform', 'joke'):0.05
# ('joke', 'good'):0.012422360248447204
# ('good', 'perform'):0.01818181818181818
# ('perform', 'peopl'):0.025
# ('peopl', 'rave'):0.02127659574468085
# ('rave', 'drive'):0.5
# ('drive', 'mad'):0.3333333333333333
# ('mad', 'either'):0.16666666666666666
# ('either', 'seen'):0.3333333333333333
# ('seen', 'mani'):0.10344827586206896
# ('mani', 'move'):0.0967741935483871
# ('move', 'seen'):0.07692307692307693
# ('mani', 'movi'):0.03225806451612903
# ('movi', 'bang'):0.008620689655172414
# ('bang', 'averag'):0.6666666666666666
# ('averag', 'actual'):0.25
# ('actual', 'bore'):0.047619047619047616
# ('bore', 'actual'):0.05
# ('actual', 'think'):0.047619047619047616
# ('think', 'leav'):0.04
# ('leav', 'half'):0.14285714285714285
# ('half', 'way'):0.5
# ('way', 'bore'):0.06060606060606061
# ('bore', 'mind'):0.05
# ('mind', 'regret'):0.2
# ('regret', 'watch'):1.0
# ('watch', 'overhyp'):0.022222222222222223
# ('overhyp', 'confus'):0.2
# ('confus', 'right'):0.3333333333333333
# ('right', 'think'):0.1
# ('think', 'good'):0.08
# ('good', 'premis'):0.01818181818181818
# ('premis', 'could'):0.5
# ('could', 'much'):0.04
# ('much', 'much'):0.03571428571428571
# ('much', 'sign'):0.03571428571428571
# ('sign', 'great'):0.3333333333333333
# ('great', 'movi'):0.10344827586206896
# ('movi', 'repeat'):0.004310344827586207
# ('repeat', 'view'):1.0
# ('view', 'move'):0.5
# ('move', 'joke'):0.05128205128205128
# ('joke', 'move'):0.006211180124223602
# ('move', 'whatsoev'):0.02564102564102564
# ('whatsoev', 'would'):0.5
# ('would', 'watch'):0.03225806451612903
# ('watch', 'thought'):0.022222222222222223
# ('thought', 'mayb'):0.07142857142857142
# ('mayb', 'peopl'):0.1111111111111111
# ('peopl', 'get'):0.02127659574468085
# ('get', 'paid'):0.03225806451612903
# ('paid', 'write'):0.5
# ('write', 'good'):0.2222222222222222
# ('good', 'review'):0.01818181818181818
# ('review', 'actual'):0.04
# ('actual', 'met'):0.047619047619047616
# ('met', 'peopl'):1.0
# ('think', 'best'):0.04
# ('movi', 'ever'):0.004310344827586207
# ('ever', 'ogg'):0.0625
# ('ogg', 'movi'):1.0
# ('averag', 'way'):0.25
# ('way', 'overhyp'):0.030303030303030304
# ('overhyp', 'phoenix'):0.2
# ('phoenix', 'perform'):0.06451612903225806
# ('perform', 'good'):0.025
# ('execut', 'bad'):0.25
# ('bad', 'feel'):0.05263157894736842
# ('feel', 'never'):0.02564102564102564
# ('never', 'even'):0.07692307692307693
# ('even', 'touch'):0.03225806451612903
# ('touch', 'higher'):0.25
# ('higher', 'spectrum'):1.0
# ('spectrum', 'perform'):1.0
# ('perform', 'could'):0.025
# ('could', 'charact'):0.04
# ('charact', 'experienc'):0.01639344262295082
# ('experienc', 'seen'):0.5
# ('seen', 'wors'):0.034482758620689655
# ('wors', 'life'):0.3333333333333333
# ('life', 'made'):0.05555555555555555
# ('made', 'feel'):0.13636363636363635
# ('feel', 'hate'):0.02564102564102564
# ('hate', 'word'):0.14285714285714285
# ('word', 'use'):0.5
# ('use', 'snowflak'):0.2
# ('snowflak', 'plea'):1.0
# ('plea', 'get'):0.2
# ('get', 'social'):0.03225806451612903
# ('social', 'medium'):0.3333333333333333
# ('medium', 'live'):1.0
# ('live', 'life'):0.25
# ('life', 'real'):0.05555555555555555
# ('real', 'world'):0.06666666666666667
# ('world', 'joaquin'):0.1
# ('give', 'heath'):0.05
# ('ledger', 'run'):0.05
# ('run', 'money'):1.0
# ('money', 'true'):0.1111111111111111
# ('true', 'stori'):0.125
# ('stori', 'popcorn'):0.02857142857142857
# ('popcorn', 'fluff'):1.0
# ('fluff', 'comic'):0.5
# ('book', 'flick'):0.1111111111111111
# ('flick', 'take'):0.5
# ('take', 'kiss'):0.041666666666666664
# ('kiss', 'see'):0.3333333333333333
# ('movi', 'shut'):0.004310344827586207
# ('shut', 'ballot'):1.0
# ('ballot', 'oscar'):1.0
# ('oscar', 'joaquin'):0.043478260869565216
# ('joaquin', 'take'):0.01818181818181818
# ('take', 'one'):0.08333333333333333
# ('one', 'home'):0.0196078431372549
# ('home', 'hand'):0.5
# ('hand', 'one'):0.14285714285714285
# ('best', 'origin'):0.03333333333333333
# ('origin', 'stori'):0.3076923076923077
# ('stori', 'ever'):0.02857142857142857
# ('ever', 'put'):0.0625
# ('put', 'downsid'):0.07692307692307693
# ('downsid', 'movi'):1.0
# ('movi', 'stand'):0.004310344827586207
# ('stand', 'alon'):0.5
# ('alon', 'film'):0.25
# ('film', 'sequel'):0.011627906976744186
# ('sequel', 'tie'):1.0
# ('tie', 'do'):0.3333333333333333
# ('do', 'univers'):0.15789473684210525
# ('univers', 'told'):0.125
# ('told', 'philip'):0.125
# ('philip', 'take'):0.3333333333333333
# ('joke', 'one'):0.012422360248447204
# ('one', 'pure'):0.0196078431372549
# ('pure', 'brillianc'):0.5
# ('brillianc', 'joaquin'):0.5
# ('phoenix', 'joke'):0.016129032258064516
# ('deserv', 'didn'):0.09090909090909091
# ('didn', 'steal'):0.1
# ('steal', 'jack'):1.0
# ('jack', 'heath'):0.25
# ('heath', 'yet'):0.05555555555555555
# ('yet', 'got'):0.14285714285714285
# ('got', 'tast'):0.125
# ('tast', 'music'):1.0
# ('music', 'intens'):0.14285714285714285
# ('intens', 'realism'):0.5
# ('realism', 'perform'):1.0
# ('perform', 'stori'):0.025
# ('stori', 'perfect'):0.05714285714285714
# ('perfect', 'combin'):0.09090909090909091
# ('combin', 'everyth'):0.5
# ('everyth', 'never'):0.08333333333333333
# ('never', 'felt'):0.07692307692307693
# ('felt', 'charact'):0.07142857142857142
# ('charact', 'like'):0.01639344262295082
# ('like', 'joke'):0.016129032258064516
# ('joke', 'could'):0.006211180124223602
# ('could', 'real'):0.04
# ('real', 'saw'):0.06666666666666667
# ('saw', 'phoenix'):0.16666666666666666
# ('phoenix', 'show'):0.016129032258064516
# ('show', 'u'):0.17647058823529413
# ('u', 'joke'):0.06666666666666667
# ('joke', 'societi'):0.012422360248447204
# ('societi', 'show'):0.058823529411764705
# ('u', 'power'):0.06666666666666667
# ('power', 'obtain'):0.16666666666666666
# ('obtain', 'philip'):1.0
# ('philip', 'hand'):0.3333333333333333
# ('hand', 'perfect'):0.14285714285714285
# ('perfect', 'choic'):0.09090909090909091
# ('choic', 'music'):0.25
# ('music', 'camera'):0.14285714285714285
# ('camera', 'angl'):0.5
# ('angl', 'light'):0.5
# ('light', 'everi'):0.25
# ('everi', 'import'):0.125
# ('import', 'factor'):0.16666666666666666
# ('factor', 'overal'):1.0
# ('overal', 'expect'):0.14285714285714285
# ('expect', 'stori'):0.058823529411764705
# ('perfect', 'mani'):0.09090909090909091
# ('mani', 'shock'):0.03225806451612903
# ('shock', 'turn'):0.3333333333333333
# ('turn', 'happen'):0.25
# ('happen', 'realli'):0.05555555555555555
# ('realli', 'repres'):0.029411764705882353
# ('repres', 'today'):0.5
# ('today', 'societi'):0.5
# ('societi', 'first'):0.058823529411764705
# ('first', 'screen'):0.07142857142857142
# ('screen', 'would'):0.16666666666666666
# ('would', 'applaus'):0.03225806451612903
# ('applaus', '80'):0.3333333333333333
# ('80', 'min'):1.0
# ('min', '8'):1.0
# ('8', 'say'):0.5
# ('say', 'write'):0.027777777777777776
# ('write', 'great'):0.1111111111111111
# ('great', 'exampl'):0.034482758620689655
# ('exampl', 'good'):0.25
# ('act', 'product'):0.023255813953488372
# ('product', 'valu'):1.0
# ('valu', 'can'):0.3333333333333333
# ('not', 'save'):0.3333333333333333
# ('save', 'script'):0.5
# ('script', 'step'):0.3333333333333333
# ('step', 'tiresom'):0.3333333333333333
# ('tiresom', 'stereotyp'):1.0
# ('stereotyp', 'failur'):1.0
# ('failur', 'delv'):0.5
# ('delv', 'charact'):1.0
# ('charact', 'ident'):0.01639344262295082
# ('ident', 'meet'):1.0
# ('meet', 'joke'):0.5
# ('joke', 'alreadi'):0.006211180124223602
# ('alreadi', 'balanc'):0.2
# ('balanc', 'call'):1.0
# ('call', 'descent'):0.09090909090909091
# ('descent', 'mad'):0.3333333333333333
# ('mad', 'realli'):0.16666666666666666
# ('realli', 'coupl'):0.029411764705882353
# ('coupl', 'week'):0.3333333333333333
# ('week', 'away'):1.0
# ('away', 'far'):0.14285714285714285
# ('far', 'descent'):0.07142857142857142
# ('descent', 'stroll'):0.3333333333333333
# ('stroll', 'charact'):1.0
# ('charact', 'studi'):0.06557377049180328
# ('studi', 'despit'):0.25
# ('despit', 'claim'):0.2
# ('claim', 'contrari'):0.2
# ('contrari', 'showcas'):0.5
# ('showcas', 'good'):0.5
# ('good', 'actor'):0.01818181818181818
# ('actor', 'overlay'):0.05555555555555555
# ('overlay', 'contort'):0.25
# ('contort', 'bodi'):1.0
# ('bodi', 'laugh'):1.0
# ('laugh', 'magic'):0.05263157894736842
# ('magic', 'mistaken'):0.3333333333333333
# ('mistaken', 'express'):1.0
# ('express', 'mad'):0.3333333333333333
# ('mad', 'past'):0.16666666666666666
# ('past', 'influenc'):0.16666666666666666
# ('influenc', 'conflict'):1.0
# ('conflict', 'semin'):1.0
# ('semin', 'moment'):1.0
# ('moment', 'creat'):0.09090909090909091
# ('creat', 'spiral'):0.2
# ('spiral', 'perhap'):1.0
# ('perhap', 'realli'):0.3333333333333333
# ('realli', 'relationship'):0.029411764705882353
# ('relationship', 'gone'):0.5
# ('gone', 'sour'):0.5
# ('sour', 'would'):1.0
# ('would', 'justifi'):0.03225806451612903
# ('justifi', 'descent'):0.25
# ('descent', 'instead'):0.3333333333333333
# ('instead', 'fait'):0.14285714285714285
# ('fait', 'accompli'):1.0
# ('accompli', 'lazi'):1.0
# ('lazi', 'write'):1.0
# ('write', 'focus'):0.1111111111111111
# ('focus', 'fanci'):0.3333333333333333
# ('fanci', 'long'):1.0
# ('long', 'shot'):0.09090909090909091
# ('shot', 'joaquin'):0.5
# ('phoenix', 'danc'):0.016129032258064516
# ('danc', 'crazi'):0.16666666666666666
# ('crazi', 'produc'):0.125
# ('produc', 'someth'):0.2
# ('someth', 'valu'):0.08333333333333333
# ('valu', 'franchis'):0.3333333333333333
# ('franchis', 'beyond'):1.0
# ('beyond', 'pathet'):0.3333333333333333
# ('pathet', 'taxi'):0.5
# ('taxi', 'divert'):0.07142857142857142
# ('divert', 'comedi'):1.0
# ('comedi', 'trepoff'):0.16666666666666666
# ('trepoff', 'briefest'):1.0
# ('briefest', 'object'):1.0
# ('object', 'singl'):1.0
# ('singl', 'worstcomplet'):0.2
# ('worstcomplet', 'nonexist'):1.0
# ('nonexist', 'version'):1.0
# ('version', 'joke'):0.36363636363636365
# ('joke', 'charact'):0.043478260869565216
# ('charact', 'histori'):0.01639344262295082
# ('histori', 'trollworthi'):0.16666666666666666
# ('trollworthi', 'masterpiec'):1.0
# ('masterpiec', 'review'):0.05
# ('review', 'dictionari'):0.04
# ('dictionari', 'definit'):1.0
# ('definit', 'proof'):0.07692307692307693
# ('proof', 'easi'):1.0
# ('easi', 'fool'):0.2
# ('fool', 'laughabl'):0.5
# ('laughabl', 'careless'):1.0
# ('careless', 'sheep'):1.0
# ('sheep', 'keep'):1.0
# ('keep', 'cri'):0.08333333333333333
# ('cri', 'societi'):0.2
# ('societi', 'cring'):0.058823529411764705
# ('cring', 'lower'):0.16666666666666666
# ('lower', 'inch'):0.2
# ('inch', 'perfect'):1.0
# ('perfect', 'portrait'):0.09090909090909091
# ('portrait', 'declin'):1.0
# ('declin', 'insan'):0.5
# ('insan', 'joaquin'):0.2857142857142857
# ('phoenix', 'portray'):0.016129032258064516
# ('portray', 'fearlessli'):0.09090909090909091
# ('fearlessli', 'perform'):1.0
# ('perform', 'lifetim'):0.05
# ('lifetim', 'choreograph'):0.5
# ('choreograph', 'impecc'):1.0
# ('impecc', 'told'):1.0
# ('phillip', 'noth'):0.1
# ('noth', 'short'):0.1111111111111111
# ('short', 'breathtak'):0.14285714285714285
# ('breathtak', 'cinematographi'):0.5
# ('cinematographi', 'backdrop'):0.0625
# ('backdrop', 'ideolog'):1.0
# ('ideolog', 'origin'):1.0
# ('origin', 'film'):0.15384615384615385
# ('film', 'complex'):0.011627906976744186
# ('complex', 'charact'):0.5
# ('charact', 'compliment'):0.01639344262295082
# ('compliment', 'superb'):1.0
# ('superb', 'soundtrack'):0.3333333333333333
# ('soundtrack', 'act'):0.25
# ('act', 'hauntingli'):0.023255813953488372
# ('hauntingli', 'beauti'):1.0
# ('beauti', 'film'):0.5
# ('film', 'definit'):0.011627906976744186
# ('definit', '1010'):0.07692307692307693
# ('1010', 'edit'):0.16666666666666666
# ('edit', 'bring'):0.3333333333333333
# ('bring', 'part'):0.16666666666666666
# ('part', '2'):0.06666666666666667
# ('2', 'plssssss'):0.09090909090909091
# ('plssssss', 'want'):1.0
# ('want', 'realli'):0.03225806451612903
# ('realli', 'slow'):0.029411764705882353
# ('slow', 'pace'):0.2
# ('pace', 'bore'):0.3333333333333333
# ('bore', 'overhyp'):0.05
# ('overhyp', 'opinion'):0.2
# ('opinion', 'phoenix'):0.14285714285714285
# ('phoenix', 'convinc'):0.03225806451612903
# ('convinc', 'alway'):0.25
# ('alway', 'meant'):0.25
# ('meant', 'joke'):0.3333333333333333
# ('joke', 'movi'):0.043478260869565216
# ('movi', 'went'):0.004310344827586207
# ('went', 'beyond'):0.07142857142857142
# ('beyond', 'expect'):0.3333333333333333
# ('expect', 'mani'):0.058823529411764705
# ('mani', 'emot'):0.03225806451612903
# ('emot', 'went'):0.2222222222222222
# ('went', 'coupl'):0.07142857142857142
# ('coupl', 'hour'):0.3333333333333333
# ('hour', 'think'):0.07692307692307693
# ('think', 'rate'):0.04
# ('rate', 'r'):0.08333333333333333
# ('r', 'phoenix'):1.0
# ('phoenix', 'abl'):0.016129032258064516
# ('abl', 'clock'):0.25
# ('clock', 'joke'):1.0
# ('joke', 'full'):0.006211180124223602
# ('full', 'psychic'):0.25
# ('psychic', 'potenti'):0.25
# ('potenti', 'charact'):0.2
# ('charact', 'meant'):0.01639344262295082
# ('meant', 'amaz'):0.3333333333333333
# ('amaz', 'stori'):0.15384615384615385
# ('stori', 'call'):0.02857142857142857
# ('call', 'mean'):0.09090909090909091
# ('mean', 'build'):0.1111111111111111
# ('build', 'second'):0.1
# ('second', 'movi'):0.3333333333333333
# ('movi', 'mayb'):0.004310344827586207
# ('mayb', 'one'):0.1111111111111111
# ('one', 'batman'):0.0196078431372549
# ('batman', 'hope'):0.05263157894736842
# ('hope', 'high'):0.045454545454545456
# ('high', 'point'):0.07692307692307693
# ('point', 'nevertheless'):0.05
# ('nevertheless', 'brilliant'):1.0
# ('brilliant', 'goddamn'):0.14285714285714285
# ('goddamn', 'movi'):1.0
# ('best', 'joke'):0.06666666666666667
# ('joke', 'ever'):0.012422360248447204
# ('ever', 'play'):0.0625
# ('play', 'hand'):0.0625
# ('hand', 'pool'):0.14285714285714285
# ('pool', 'need'):0.3333333333333333
# ('need', 'money'):0.05555555555555555
# ('money', 'need'):0.1111111111111111
# ('need', 'digniti'):0.05555555555555555
# ('digniti', 'respect'):1.0
# ('respect', 'co'):0.5
# ('co', 'take'):1.0
# ('take', 'human'):0.041666666666666664
# ('human', 'dont'):0.3333333333333333
# ('dont', 'money'):0.03225806451612903
# ('money', 'remind'):0.1111111111111111
# ('remind', 'good'):0.25
# ('good', 'boy'):0.01818181818181818
# ('boy', 'like'):0.25
# ('like', 'politician'):0.016129032258064516
# ('politician', 'feel'):1.0
# ('feel', 'frustrat'):0.02564102564102564
# ('frustrat', 'peopl'):0.5
# ('peopl', 'lower'):0.02127659574468085
# ('lower', 'class'):0.2
# ('class', 'accept'):0.2
# ('accept', 'fund'):0.5
# ('fund', 'champion'):1.0
# ('champion', 'movi'):1.0
# ('movi', 'joke'):0.017241379310344827
# ('joke', 'life'):0.006211180124223602
# ('life', 'begin'):0.05555555555555555
# ('begin', 'get'):0.125
# ('get', 'expect'):0.03225806451612903
# ('expect', 'masterpiec'):0.058823529411764705
# ('masterpiec', 'oscar'):0.05
# ('oscar', 'worthi'):0.17391304347826086
# ('worthi', 'film'):0.14285714285714285
# ('film', 'hope'):0.011627906976744186
# ('hope', 'actual'):0.045454545454545456
# ('actual', 'didn'):0.047619047619047616
# ('didn', 'enjoy'):0.1
# ('enjoy', 'watch'):0.14285714285714285
# ('watch', 'movi'):0.08888888888888889
# ('movi', 'messag'):0.004310344827586207
# ('messag', 'slow'):0.14285714285714285
# ('slow', 'joke'):0.1
# ('joke', 'turn'):0.006211180124223602
# ('turn', 'son'):0.25
# ('son', 'schizophren'):0.3333333333333333
# ('schizophren', 'went'):1.0
# ('went', 'crazi'):0.07142857142857142
# ('crazi', 'slight'):0.125
# ('slight', 'amount'):1.0
# ('amount', 'build'):1.0
# ('build', 'dont'):0.1
# ('dont', 'see'):0.06451612903225806
# ('see', 'anyon'):0.03333333333333333
# ('anyon', 'could'):0.25
# ('could', 'relat'):0.04
# ('relat', 'charact'):0.14285714285714285
# ('charact', 'laugh'):0.01639344262295082
# ('laugh', 'lame'):0.05263157894736842
# ('lame', 'act'):1.0
# ('act', 'way'):0.023255813953488372
# ('way', 'everyon'):0.030303030303030304
# ('everyon', 'in'):0.08333333333333333
# ('in', 'stun'):0.1
# ('stun', '910'):0.2
# ('910', 'rate'):0.5
# ('rate', 'right'):0.08333333333333333
# ('right', 'hell'):0.1
# ('hell', 'thought'):0.3333333333333333
# ('thought', 'movi'):0.07142857142857142
# ('movi', 'complet'):0.004310344827586207
# ('complet', 'utter'):0.07142857142857142
# ('utter', 'garag'):0.5
# ('garag', 'dont'):0.5
# ('dont', 'understand'):0.0967741935483871
# ('understand', 'peopl'):0.06666666666666667
# ('peopl', 'like'):0.0851063829787234
# ('like', 'movi'):0.03225806451612903
# ('much', 'charact'):0.10714285714285714
# ('charact', 'doesn'):0.01639344262295082
# ('doesn', 'even'):0.1
# ('even', 'stay'):0.03225806451612903
# ('stay', 'true'):0.3333333333333333
# ('true', 'comic'):0.125
# ('comic', 'director'):0.043478260869565216
# ('director', 'flat'):0.125
# ('flat', 'said'):0.3333333333333333
# ('said', 'didn'):0.14285714285714285
# ('didn', 'made'):0.1
# ('made', 'seem'):0.09090909090909091
# ('seem', 'like'):0.25
# ('like', 'part'):0.016129032258064516
# ('part', 'gotham'):0.06666666666666667
# ('gotham', 'fall'):1.0
# ('fall', 'littl'):0.16666666666666666
# ('littl', 'boy'):0.1111111111111111
# ('boy', 'laugh'):0.25
# ('laugh', 'problem'):0.05263157894736842
# ('problem', 'hate'):0.25
# ('hate', '1010'):0.14285714285714285
# ('1010', 'amaz'):0.16666666666666666
# ('stori', 'brilliant'):0.02857142857142857
# ('brilliant', 'take'):0.14285714285714285
# ('take', 'magnific'):0.041666666666666664
# ('magnific', 'cinematographi'):1.0
# ('cinematographi', 'someon'):0.0625
# ('someon', 'step'):0.25
# ('step', 'safe'):0.3333333333333333
# ('safe', 'game'):0.5
# ('game', 'play'):0.5
# ('play', 'superhero'):0.0625
# ('also', 'boy'):0.058823529411764705
# ('boy', 'movi'):0.25
# ('movi', 'gritti'):0.004310344827586207
# ('gritti', 'real'):0.3333333333333333
# ('real', 'insan'):0.06666666666666667
# ('insan', 'dark'):0.14285714285714285
# ('dark', 'sometim'):0.03571428571428571
# ('sometim', 'quit'):0.25
# ('quit', 'disturb'):0.09090909090909091
# ('disturb', 'peopl'):0.1
# ('peopl', 'dont'):0.02127659574468085
# ('dont', 'want'):0.0967741935483871
# ('want', 'accept'):0.03225806451612903
# ('accept', 'what'):0.5
# ('what', 'shown'):0.3333333333333333
# ('shown', 'movi'):0.3333333333333333
# ('movi', 'terribl'):0.01293103448275862
# ('terribl', 'realiti'):0.16666666666666666
# ('realiti', 'face'):0.2
# ('face', 'everyday'):0.16666666666666666
# ('everyday', 'refus'):1.0
# ('refus', 'proper'):1.0
# ('proper', 'care'):0.16666666666666666
# ('care', 'normal'):0.25
# ('normal', 'peopl'):0.3333333333333333
# ('peopl', 'start'):0.02127659574468085
# ('start', 'compar'):0.09090909090909091
# ('compar', 'movi'):0.5
# ('movi', 'one'):0.004310344827586207
# ('one', 'greatest'):0.0392156862745098
# ('greatest', 'like'):0.4
# ('like', 'dark'):0.04838709677419355
# ('knight', 'act'):0.1
# ('act', 'wise'):0.023255813953488372
# ('wise', 'heath'):1.0
# ('ledger', 'betray'):0.05
# ('betray', 'joke'):1.0
# ('joke', 'wouldn'):0.006211180124223602
# ('wouldn', 'say'):0.25
# ('movi', 'better'):0.004310344827586207
# ('better', 'otherwis'):0.045454545454545456
# ('otherwis', 'stand'):0.3333333333333333
# ('stand', 'tall'):0.5
# ('tall', 'amongst'):1.0
# ('amongst', 'greatest'):1.0
# ('like', 'godfath'):0.016129032258064516
# ('godfath', 'taxi'):1.0
# ('driver', 'citizen'):0.07692307692307693
# ('citizen', 'lane'):0.5
# ('lane', 'dark'):1.0
# ('knight', 'come'):0.1
# ('come', 'inevit'):0.06666666666666667
# ('inevit', 'comparison'):0.3333333333333333
# ('comparison', 'who'):0.25
# ('who', 'better'):0.25
# ('better', 'joke'):0.09090909090909091
# ('joke', 'heath'):0.012422360248447204
# ('heath', 'joaquin'):0.05555555555555555
# ('joaquin', 'answer'):0.01818181818181818
# ('answer', 'phenomenon'):0.3333333333333333
# ('phenomenon', 'job'):0.3333333333333333
# ('job', 'joke'):0.3333333333333333
# ('charact', 'fortun'):0.01639344262295082
# ('fortun', 'play'):1.0
# ('play', 'two'):0.0625
# ('two', 'greatest'):0.1111111111111111
# ('greatest', 'actor'):0.2
# ('actor', 'definit'):0.05555555555555555
# ('definit', 'top'):0.15384615384615385
# ('top', 'contend'):0.3333333333333333
# ('contend', 'scar'):1.0
# ('scar', 'person'):0.14285714285714285
# ('person', 'think'):0.05
# ('think', 'would'):0.04
# ('would', 'take'):0.03225806451612903
# ('take', 'away'):0.041666666666666664
# ('away', 'best'):0.14285714285714285
# ('best', 'actor'):0.06666666666666667
# ('actor', '2cinematographi'):0.05555555555555555
# ('2cinematographi', 'origin'):1.0
# ('origin', 'score'):0.07692307692307693
# ('score', 'upon'):0.07142857142857142
# ('hollywood', 'lose'):0.14285714285714285
# ('lose', 'make'):0.5
# ('make', 'hairstyl'):0.025
# ('hairstyl', 'categori'):1.0
# ('categori', 'would'):0.3333333333333333
# ('would', 'definit'):0.03225806451612903
# ('definit', 'joke'):0.07692307692307693
# ('joke', 'whole'):0.006211180124223602
# ('whole', 'point'):0.18181818181818182
# ('point', 'movi'):0.15
# ('movi', 'bring'):0.004310344827586207
# ('bring', 'attent'):0.16666666666666666
# ('attent', 'mental'):0.25
# ('ill', 'ill'):0.037037037037037035
# ('ill', 'one'):0.037037037037037035
# ('one', 'better'):0.0196078431372549
# ('better', 'name'):0.045454545454545456
# ('name', 'bigger'):0.25
# ('bigger', 'issu'):0.5
# ('issu', 'mental'):0.2
# ('ill', 'film'):0.037037037037037035
# ('film', 'bare'):0.011627906976744186
# ('bare', 'focus'):0.5
# ('focus', 'lack'):0.3333333333333333
# ('lack', 'qualiti'):0.125
# ('qualiti', 'mental'):0.25
# ('mental', 'healthcar'):0.03333333333333333
# ('healthcar', 'film'):1.0
# ('film', 'complet'):0.011627906976744186
# ('complet', 'discredit'):0.07142857142857142
# ('discredit', 'messag'):1.0
# ('messag', 'one'):0.14285714285714285
# ('one', 'dimens'):0.0392156862745098
# ('dimens', 'deduct'):0.5
# ('deduct', 'world'):0.6666666666666666
# ('world', 'charact'):0.1
# ('charact', 'inhabit'):0.01639344262295082
# ('inhabit', 'seem'):1.0
# ('seem', 'gothic'):0.08333333333333333
# ('gothic', 'citizen'):0.2
# ('citizen', 'entir'):0.5
# ('entir', 'univers'):0.16666666666666666
# ('univers', 'matter'):0.125
# ('matter', 'exist'):0.5
# ('exist', 'put'):0.25
# ('put', 'arthur'):0.07692307692307693
# ('arthur', 'consid'):0.05555555555555555
# ('consid', 'film'):0.1111111111111111
# ('film', 'isn'):0.011627906976744186
# ('isn', 'told'):0.1
# ('told', 'arthur'):0.0625
# ('arthur', 'perspect'):0.05555555555555555
# ('perspect', 'blatantli'):1.0
# ('blatantli', 'stupid'):1.0
# ('stupid', 'deduct'):0.2
# ('world', 'reason'):0.1
# ('reason', 'peopl'):0.2
# ('like', 'much'):0.016129032258064516
# ('much', 'sad'):0.03571428571428571
# ('sad', 'corpor'):0.2
# ('corpor', 'slave'):1.0
# ('slave', 'especi'):1.0
# ('especi', 'youth'):0.3333333333333333
# ('youth', 'current'):1.0
# ('current', 'indoctrin'):1.0
# ('indoctrin', 'unconsci'):1.0
# ('unconsci', 'trick'):1.0
# ('trick', 'believ'):1.0
# ('believ', 'part'):0.07142857142857142
# ('part', 'bigger'):0.06666666666666667
# ('bigger', 'caus'):0.5
# ('caus', 'realli'):0.2
# ('realli', 'sit'):0.029411764705882353
# ('sit', 'come'):0.3333333333333333
# ('come', 'chair'):0.13333333333333333
# ('chair', 'joaquin'):0.3333333333333333
# ('joaquin', 'portray'):0.01818181818181818
# ('portray', 'sociopath'):0.09090909090909091
# ('sociopath', 'mental'):1.0
# ('mental', 'unstabl'):0.1
# ('unstabl', 'man'):0.3333333333333333
# ('man', 'transform'):0.09090909090909091
# ('transform', 'iron'):0.25
# ('iron', 'joke'):0.3333333333333333
# ('joke', 'non'):0.006211180124223602
# ('non', 'grip'):1.0
# ('grip', 'accur'):0.3333333333333333
# ('accur', 'realist'):0.25
# ('realist', 'touch'):0.125
# ('touch', 'condit'):0.25
# ('condit', 'dark'):0.3333333333333333
# ('dark', 'disturb'):0.03571428571428571
# ('disturb', 'charact'):0.1
# ('charact', 'piec'):0.03278688524590164
# ('piec', 'led'):0.16666666666666666
# ('led', 'oscar'):1.0
# ('worthi', 'perform'):0.2857142857142857
# ('perform', 'joaquin'):0.15
# ('phoenix', 'realli'):0.04838709677419355
# ('realli', 'feel'):0.029411764705882353
# ('feel', 'bad'):0.02564102564102564
# ('bad', 'guy'):0.10526315789473684
# ('guy', 'make'):0.14285714285714285
# ('make', 'heartbreak'):0.025
# ('heartbreak', 'inevit'):1.0
# ('inevit', 'becom'):0.3333333333333333
# ('becom', 'clown'):0.1
# ('crime', 'know'):0.14285714285714285
# ('know', 'love'):0.08695652173913043
# ('love', 'although'):0.1
# ('although', 'were'):0.25
# ('were', 'never'):0.5
# ('never', 'seen'):0.15384615384615385
# ('seen', 'like'):0.034482758620689655
# ('like', 'see'):0.03225806451612903
# ('see', 'suffer'):0.03333333333333333
# ('suffer', 'throughout'):0.14285714285714285
# ('throughout', 'movi'):0.3333333333333333
# ('movi', 'point'):0.004310344827586207
# ('point', 'almost'):0.05
# ('almost', 'foot'):0.1
# ('foot', 'him'):0.5
# ('him', 'becom'):1.0
# ('becom', 'mass'):0.2
# ('mass', 'murder'):0.5
# ('murder', 'psyco'):0.2
# ('psyco', 'clown'):1.0
# ('clown', 'least'):0.08333333333333333
# ('least', 'make'):0.14285714285714285
# ('feel', 'better'):0.02564102564102564
# ('better', 'happen'):0.045454545454545456
# ('happen', 'wish'):0.05555555555555555
# ('wish', 'could'):1.0
# ('could', 'avoid'):0.04
# ('avoid', 'e'):0.5
# ('e', 'miss'):1.0
# ('miss', 'feel'):0.14285714285714285
# ('feel', 'care'):0.02564102564102564
# ('care', 'time'):0.25
# ('time', 'he'):0.024390243902439025
# ('he', 'joke'):0.1
# ('joke', 'wish'):0.006211180124223602
# ('could', 'help'):0.04
# ('help', 'there'):0.2
# ('there', 'lot'):0.2222222222222222
# ('lot', 'great'):0.07692307692307693
# ('great', 'nod'):0.034482758620689655
# ('nod', 'greater'):0.3333333333333333
# ('greater', 'batman'):1.0
# ('univers', 'yet'):0.125
# ('yet', 'movi'):0.14285714285714285
# ('movi', 'self'):0.004310344827586207
# ('self', 'contain'):1.0
# ('contain', 'charact'):1.0
# ('piec', 'mark'):0.16666666666666666
# ('mark', 'great'):0.6666666666666666
# ('movi', 'act'):0.008620689655172414
# ('act', 'great'):0.023255813953488372
# ('great', 'plot'):0.034482758620689655
# ('plot', 'similar'):0.05
# ('similar', 'taxi'):0.6666666666666666
# ('driver', 'brilliant'):0.07692307692307693
# ('brilliant', 'qualiti'):0.14285714285714285
# ('movi', 'show'):0.021551724137931036
# ('show', 'dont'):0.058823529411764705
# ('dont', 'need'):0.0967741935483871
# ('need', 'chi'):0.05555555555555555
# ('chi', 'super'):0.5
# ('super', 'power'):0.25
# ('power', 'great'):0.16666666666666666
# ('great', 'villain'):0.034482758620689655
# ('villain', 'superhero'):0.07142857142857142
# ('joke', 'everyon'):0.006211180124223602
# ('everyon', 'get'):0.08333333333333333
# ('movi', 'rise'):0.004310344827586207
# ('rise', 'joke'):0.5
# ('joke', '1010'):0.006211180124223602
# ('1010', 'one'):0.16666666666666666
# ('best', 'move'):0.1
# ('move', 'year'):0.02564102564102564
# ('year', '100'):0.07142857142857142
# ('100', 'oscar'):0.5
# ('worthi', 'joaquin'):0.14285714285714285
# ('deliv', 'one'):0.5
# ('best', 'perform'):0.06666666666666667
# ('perform', 'give'):0.025
# ('give', 'ever'):0.1
# ('ever', 'scene'):0.0625
# ('scene', 'dont'):0.05555555555555555
# ('dont', 'wast'):0.03225806451612903
# ('wast', '2'):0.16666666666666666
# ('hour', 'life'):0.23076923076923078
# ('life', 'movi'):0.05555555555555555
# ('movi', 'saddest'):0.004310344827586207
# ('saddest', 'give'):1.0
# ('give', 'seen'):0.2
# ('seen', 'long'):0.06896551724137931
# ('happi', 'write'):0.2
# ('good', 'storylineit'):0.01818181818181818
# ('storylineit', 'bore'):1.0
# ('bore', 'went'):0.05
# ('went', 'pay'):0.07142857142857142
# ('pay', 'counter'):1.0
# ('counter', 'ask'):1.0
# ('ask', 'money'):0.5
# ('money', 'back'):0.2222222222222222
# ('back', '2'):0.2
# ('hour', 'torturethey'):0.07692307692307693
# ('torturethey', 'can'):1.0
# ('can', 'peopl'):0.1
# ('like', 'peopl'):0.016129032258064516
# ('peopl', '1010'):0.02127659574468085
# ('1010', 'reason'):0.16666666666666666
# ('reason', 'went'):0.2
# ('went', 'your'):0.07142857142857142
# ('your', 'joke'):0.16666666666666666
# ('joke', 'want'):0.018633540372670808
# ('want', 'titl'):0.03225806451612903
# ('titl', 'make'):0.2
# ('make', 'wouldn'):0.025
# ('wouldn', 'know'):0.25
# ('know', 'base'):0.043478260869565216
# ('base', 'comicbook'):0.2
# ('comicbook', 'charact'):0.5
# ('charact', 'first'):0.03278688524590164
# ('first', 'real'):0.07142857142857142
# ('real', 'joke'):0.13333333333333333
# ('joke', 'weak'):0.006211180124223602
# ('weak', 'confid'):0.3333333333333333
# ('confid', 'pushov'):0.3333333333333333
# ('pushov', 'even'):1.0
# ('even', 'genesi'):0.03225806451612903
# ('genesi', 'stage'):1.0
# ('stage', 'real'):1.0
# ('joke', 'high'):0.006211180124223602
# ('high', 'toler'):0.07692307692307693
# ('toler', 'pain'):1.0
# ('pain', 'could'):0.16666666666666666
# ('could', 'fight'):0.04
# ('fight', 'intellig'):0.25
# ('intellig', 'made'):0.14285714285714285
# ('made', 'danger'):0.045454545454545456
# ('danger', 'due'):0.3333333333333333
# ('due', 'insan'):0.5
# ('joaquin', 'shoot'):0.01818181818181818
# ('shoot', 'guy'):0.3333333333333333
# ('guy', 'subway'):0.14285714285714285
# ('subway', 'cowardic'):1.0
# ('cowardic', 'tri'):1.0
# ('tri', 'make'):0.16666666666666666
# ('make', 'murray'):0.025
# ('murray', 'shoot'):0.5
# ('shoot', 'scene'):0.3333333333333333
# ('scene', 'way'):0.05555555555555555
# ('way', 'joaquin'):0.030303030303030304
# ('joaquin', 'joke'):0.03636363636363636
# ('ever', 'fill'):0.0625
# ('fill', 'shoe'):0.3333333333333333
# ('shoe', 'adam'):1.0
# ('adam', 'joke'):1.0
# ('joke', 'comic'):0.018633540372670808
# ('comic', 'even'):0.043478260869565216
# ('even', 'differ'):0.03225806451612903
# ('differ', 'inclin'):0.0625
# ('inclin', 'differ'):0.5
# ('differ', 'comic'):0.0625
# ('comic', 'authorsand'):0.043478260869565216
# ('authorsand', 'forget'):1.0
# ('forget', 'even'):0.2
# ('even', 'come'):0.03225806451612903
# ('come', 'close'):0.13333333333333333
# ('close', 'heath'):0.1
# ('ledger', 'portray'):0.1
# ('portray', 'call'):0.09090909090909091
# ('call', 'movi'):0.09090909090909091
# ('movi', 'someth'):0.004310344827586207
# ('someth', 'total'):0.08333333333333333
# ('total', 'differ'):0.25
# ('differ', 'forget'):0.0625
# ('forget', 'tri'):0.2
# ('make', 'connect'):0.025
# ('connect', 'dont'):0.3333333333333333
# ('understand', 'high'):0.06666666666666667
# ('high', 'rate'):0.15384615384615385
# ('rate', 'went'):0.08333333333333333
# ('went', 'cinema'):0.07142857142857142
# ('cinema', 'high'):0.09090909090909091
# ('high', 'expect'):0.07692307692307693
# ('expect', 'discov'):0.058823529411764705
# ('discov', 'movi'):1.0
# ('movi', 'slow'):0.008620689655172414
# ('slow', 'anyth'):0.1
# ('anyth', 'almost'):0.09090909090909091
# ('almost', 'finish'):0.1
# ('finish', 'first'):0.5
# ('first', 'kill'):0.07142857142857142
# ('kill', 'happen'):0.125
# ('happen', 'dread'):0.05555555555555555
# ('dread', 'time'):1.0
# ('time', 'wait'):0.024390243902439025
# ('wait', 'someth'):0.3333333333333333
# ('someth', 'happen'):0.08333333333333333
# ('happen', 'ye'):0.05555555555555555
# ('ye', 'movi'):0.4
# ('movi', 'finish'):0.004310344827586207
# ('finish', 'final'):0.5
# ('final', 'walk'):0.16666666666666666
# ('walk', 'got'):0.25
# ('got', 'comic'):0.125
# ('comic', 'joke'):0.043478260869565216
# ('joke', 'trust'):0.006211180124223602
# ('trust', 'review'):1.0
# ('review', 'leav'):0.04
# ('leav', 'disappoint'):0.14285714285714285
# ('disappoint', 'disbeliev'):0.25
# ('disbeliev', 'actual'):1.0
# ('actual', 'paid'):0.047619047619047616
# ('paid', 'watch'):0.5
# ('watch', 'serious'):0.022222222222222223
# ('serious', 'unbeliev'):0.2
# ('unbeliev', 'dare'):1.0
# ('dare', 'say'):0.3333333333333333
# ('say', 'better'):0.027777777777777776
# ('better', 'heath'):0.09090909090909091
# ('ledger', 'joaquin'):0.05
# ('doesn', 'win'):0.2
# ('win', 'oscar'):0.2222222222222222
# ('oscar', 'best'):0.043478260869565216
# ('actor', 'joke'):0.05555555555555555
# ('joke', 'doesn'):0.012422360248447204
# ('win', 'least'):0.1111111111111111
# ('least', 'best'):0.14285714285714285
# ('best', 'screenplay'):0.03333333333333333
# ('screenplay', 'one'):0.16666666666666666
# ('one', 'biggest'):0.0196078431372549
# ('biggest', 'oscar'):1.0
# ('oscar', 'snub'):0.043478260869565216
# ('snub', 'time'):1.0
# ('time', 'film'):0.04878048780487805
# ('film', 'mental'):0.023255813953488372
# ('ill', 'specif'):0.037037037037037035
# ('specif', 'mental'):1.0
# ('ill', 'call'):0.037037037037037035
# ('call', 'creativ'):0.09090909090909091
# ('creativ', 'diarrhoea'):0.25
# ('diarrhoea', 'serious'):1.0
# ('serious', 'though'):0.2
# ('though', 'soon'):0.1
# ('soon', 'much'):1.0
# ('much', 'wrong'):0.03571428571428571
# ('wrong', 'movi'):0.1
# ('movi', 'wont'):0.004310344827586207
# ('wont', 'even'):0.2
# ('even', 'start'):0.03225806451612903
# ('start', 'knew'):0.09090909090909091
# ('knew', 'joke'):0.5
# ('joke', 'sob'):0.006211180124223602
# ('sob', 'stori'):1.0
# ('stori', 'hope'):0.02857142857142857
# ('hope', 'artist'):0.045454545454545456
# ('artist', 'success'):0.5
# ('success', 'went'):0.3333333333333333
# ('went', 'went'):0.07142857142857142
# ('went', 'see'):0.14285714285714285
# ('see', 'anyway'):0.03333333333333333
# ('anyway', 'ill'):0.3333333333333333
# ('ill', 'start'):0.037037037037037035
# ('start', 'point'):0.09090909090909091
# ('point', 'review'):0.05
# ('review', 'observ'):0.04
# ('observ', 'even'):1.0
# ('even', 'joke'):0.06451612903225806
# ('joke', 'he'):0.006211180124223602
# ('he', 'suav'):0.1
# ('suav', 'he'):1.0
# ('he', 'witti'):0.1
# ('witti', 'lethal'):1.0
# ('lethal', 'gimmick'):1.0
# ('gimmick', 'morbid'):1.0
# ('morbid', 'joke'):1.0
# ('joke', 'anarchist'):0.006211180124223602
# ('anarchist', 'isn'):1.0
# ('isn', 'crimin'):0.1
# ('crimin', 'master'):0.3333333333333333
# ('master', 'he'):0.2
# ('he', 'lower'):0.1
# ('lower', 'goe'):0.2
# ('goe', 'school'):0.5
# ('school', 'shorter'):0.5
# ('shorter', 'streak'):1.0
# ('streak', 'secondli'):1.0
# ('secondli', 'said'):0.5
# ('said', 'earlier'):0.14285714285714285
# ('earlier', 'film'):0.5
# ('ill', 'monkey'):0.037037037037037035
# ('monkey', 'wash'):0.5
# ('wash', 'increas'):1.0
# ('increas', 'awar'):1.0
# ('awar', 'mental'):1.0
# ('mental', 'health'):0.13333333333333333
# ('health', 'one'):0.25
# ('one', 'concept'):0.0196078431372549
# ('concept', 'sycosi'):1.0
# ('sycosi', 'mental'):1.0
# ('health', 'problem'):0.25
# ('problem', 'judici'):0.25
# ('judici', 'explor'):1.0
# ('explor', 'movi'):1.0
# ('movi', 'ill'):0.004310344827586207
# ('ill', 'caus'):0.037037037037037035
# ('caus', 'suffer'):0.2
# ('suffer', 'laugh'):0.14285714285714285
# ('laugh', 'inappropri'):0.05263157894736842
# ('inappropri', 'situat'):0.5
# ('situat', 'serious'):0.3333333333333333
# ('serious', 'your'):0.2
# ('your', 'get'):0.16666666666666666
# ('get', 'downtrodden'):0.03225806451612903
# ('downtrodden', 'longer'):1.0
# ('longer', 'subject'):0.3333333333333333
# ('subject', 'beat'):0.5
# ('beat', 'injustic'):1.0
# ('injustic', 'design'):0.5
# ('design', 'spark'):0.3333333333333333
# ('spark', 'indign'):1.0
# ('indign', 'viewer'):1.0
# ('viewer', 'go'):0.3333333333333333
# ('go', 'murder'):0.041666666666666664
# ('murder', 'spree'):0.2
# ('spree', 'regard'):1.0
# ('regard', 'muchprais'):0.5
# ('muchprais', 'act'):1.0
# ('act', 'mysteri'):0.023255813953488372
# ('mysteri', 'anyon'):1.0
# ('could', 'come'):0.04
# ('come', 'judgement'):0.06666666666666667
# ('judgement', 'phoenix'):1.0
# ('phoenix', 'theatric'):0.016129032258064516
# ('theatric', 'achiev'):0.5
# ('achiev', 'base'):0.5
# ('base', 'quinin'):0.2
# ('quinin', 'script'):1.0
# ('script', 'can'):0.3333333333333333
# ('can', 'devot'):0.1
# ('devot', 'iota'):1.0
# ('iota', 'attent'):1.0
# ('attent', 'posit'):0.25
# ('posit', 'review'):0.2
# ('review', 'in'):0.04
# ('in', 'fairli'):0.1
# ('fairli', 'confid'):1.0
# ('confid', 'largescal'):0.3333333333333333
# ('largescal', 'review'):1.0
# ('review', 'rig'):0.04
# ('rig', 'go'):1.0
# ('go', 'plot'):0.041666666666666664
# ('plot', 'one'):0.1
# ('dimens', 'juvenil'):0.5
# ('juvenil', 'dialogu'):1.0
# ('dialogu', 'engag'):0.2
# ('engag', 'monotoni'):0.2
# ('monotoni', 'nurseri'):1.0
# ('nurseri', 'rhyme'):1.0
# ('rhyme', 'charact'):1.0
# ('develop', 'shallow'):0.16666666666666666
# ('shallow', 'good'):0.5
# ('good', 'left'):0.01818181818181818
# ('left', 'right'):0.14285714285714285
# ('right', 'centr'):0.1
# ('centr', 'like'):1.0
# ('like', 'revolv'):0.016129032258064516
# ('revolv', 'zero'):0.2
# ('zero', 'recoil'):1.0
# ('recoil', '8'):1.0
# ('8', 'bullet'):0.5
# ('bullet', 'arthur'):1.0
# ('arthur', 'keep'):0.05555555555555555
# ('keep', 'danc'):0.08333333333333333
# ('danc', 'need'):0.16666666666666666
# ('need', 'see'):0.05555555555555555
# ('see', 'arthur'):0.03333333333333333
# ('arthur', 'foundl'):0.05555555555555555
# ('foundl', 'emaci'):1.0
# ('emaci', 'much'):1.0
# ('much', 'smoke'):0.03571428571428571
# ('smoke', 'watch'):0.3333333333333333
# ('watch', 'mani'):0.022222222222222223
# ('mani', 'close'):0.03225806451612903
# ('close', 'cigarett'):0.1
# ('cigarett', 'burn'):0.5
# ('burn', 'make'):0.5
# ('make', 'wonder'):0.025
# ('wonder', 'film'):0.25
# ('film', 'sponsor'):0.011627906976744186
# ('sponsor', 'tobacco'):1.0
# ('tobacco', 'industri'):1.0
# ('industri', 'two'):1.0
# ('two', 'posit'):0.1111111111111111
# ('posit', 'movi'):0.2
# ('movi', 'firstli'):0.004310344827586207
# ('firstli', 'final'):0.5
# ('final', 'talk'):0.16666666666666666
# ('talk', 'show'):0.16666666666666666
# ('show', 'scene'):0.058823529411764705
# ('scene', 'litter'):0.05555555555555555
# ('litter', 'though'):1.0
# ('though', 'imperfect'):0.1
# ('imperfect', 'like'):1.0
# ('like', 'rest'):0.016129032258064516
# ('rest', 'movi'):0.5
# ('movi', 'sit'):0.004310344827586207
# ('sit', 'littl'):0.3333333333333333
# ('littl', 'le'):0.1111111111111111
# ('le', 'slough'):0.14285714285714285
# ('slough', 'seat'):1.0
# ('seat', 'also'):0.25
# ('also', 'interest'):0.11764705882352941
# ('interest', 'theori'):0.125
# ('theori', 'present'):1.0
# ('present', 'tie'):0.2
# ('tie', 'joke'):0.3333333333333333
# ('joke', 'batman'):0.006211180124223602
# ('batman', 'bar'):0.05263157894736842
# ('bar', 'set'):0.6666666666666666
# ('set', 'high'):0.2857142857142857
# ('high', 'dark'):0.07692307692307693
# ('knight', 'director'):0.1
# ('director', 'seek'):0.125
# ('seek', 'artist'):1.0
# ('artist', 'claim'):0.5
# ('claim', 'go'):0.2
# ('go', 'near'):0.041666666666666664
# ('near', 'joke'):0.3333333333333333
# ('joke', 'mani'):0.006211180124223602
# ('mani', 'year'):0.03225806451612903
# ('year', 'come'):0.07142857142857142
# ('come', 'mayb'):0.06666666666666667
# ('mayb', 'ever'):0.1111111111111111
# ('ever', 'hand'):0.0625
# ('hand', 'joke'):0.14285714285714285
# ('charact', 'render'):0.01639344262295082
# ('render', 'boon'):0.5
# ('boon', 'hollywood'):1.0
# ('hollywood', 'opportun'):0.14285714285714285
# ('opportun', 'second'):0.3333333333333333
# ('second', 'time'):0.3333333333333333
# ('time', 'were'):0.024390243902439025
# ('were', 'seen'):0.5
# ('seen', 'charact'):0.034482758620689655
# ('charact', 'butcher'):0.01639344262295082
# ('butcher', 'low'):1.0
# ('low', 'effort'):0.25
# ('effort', 'high'):0.5
# ('high', 'budget'):0.07692307692307693
# ('budget', 'money'):1.0
# ('money', 'maker'):0.1111111111111111
# ('maker', 'one'):1.0
# ('one', 'forgotten'):0.0196078431372549
# ('forgotten', 'quick'):1.0
# ('quick', 'dont'):1.0
# ('dont', 'know'):0.06451612903225806
# ('know', 'long'):0.043478260869565216
# ('long', 'joke'):0.09090909090909091
# ('joke', 'recov'):0.006211180124223602
# ('recov', 'joaquín'):1.0
# ('joaquín', 'phoenix'):1.0
# ('convinc', 'laugh'):0.25
# ('laugh', 'look'):0.05263157894736842
# ('look', 'like'):0.1111111111111111
# ('like', 'beaten'):0.016129032258064516
# ('beaten', 'dog'):1.0
# ('dog', 'brutal'):1.0
# ('brutal', 'enjoy'):0.3333333333333333
# ('enjoy', '5'):0.14285714285714285
# ('5', 'minut'):0.75
# ('minut', 'world'):0.2
# ('world', 'mean'):0.1
# ('mean', 'bad'):0.1111111111111111
# ('bad', 'bad'):0.05263157894736842
# ('bad', 'hit'):0.05263157894736842
# ('hit', 'back'):0.2
# ('back', 'chao'):0.2
# ('chao', 'anarchi'):0.5
# ('anarchi', 'whatev'):1.0
# ('whatev', 'inspir'):0.5
# ('inspir', 'bye'):0.1111111111111111
# ('bye', 'clown'):1.0
# ('clown', 'kill'):0.08333333333333333
# ('kill', '3'):0.125
# ('3', 'gulli'):0.2
# ('gulli', 'stupid'):1.0
# ('stupid', 'excess'):0.2
# ('excess', 'brutal'):1.0
# ('brutal', 'name'):0.3333333333333333
# ('name', 'ye'):0.25
# ('ye', 'director'):0.2
# ('director', 'hanov'):0.25
# ('hanov', '3'):0.5
# ('3', 'dont'):0.2
# ('want', 'parti'):0.03225806451612903
# ('parti', 'brutal'):1.0
# ('brutal', 'bore'):0.3333333333333333
# ('bore', 'trailer'):0.05
# ('movi', 'may'):0.004310344827586207
# ('may', 'seem'):0.2222222222222222
# ('like', 'potenti'):0.016129032258064516
# ('potenti', 'action'):0.2
# ('action', 'pack'):0.058823529411764705
# ('pack', 'movi'):1.0
# ('movi', 'clearli'):0.008620689655172414
# ('clearli', 'came'):0.25
# ('came', 'theater'):0.3333333333333333
# ('theater', 'intend'):0.16666666666666666
# ('intend', 'progress'):1.0
# ('progress', 'charact'):1.0
# ('studi', 'shouldn'):0.25
# ('shouldn', 'go'):0.5
# ('go', 'movi'):0.041666666666666664
# ('movi', 'expect'):0.004310344827586207
# ('expect', 'intens'):0.058823529411764705
# ('intens', 'action'):0.5
# ('action', 'joke'):0.17647058823529413
# ('joke', 'know'):0.006211180124223602
# ('know', 'past'):0.043478260869565216
# ('past', 'movi'):0.16666666666666666
# ('movi', 'arthur'):0.008620689655172414
# ('arthur', 'fleck'):0.1111111111111111
# ('fleck', 'becom'):0.3333333333333333
# ('becom', 'joke'):0.2
# ('joke', 'seen'):0.006211180124223602
# ('mani', 'bad'):0.03225806451612903
# ('bad', 'review'):0.05263157894736842
# ('review', 'bore'):0.04
# ('bore', 'slow'):0.05
# ('slow', 'movi'):0.1
# ('movi', 'believ'):0.004310344827586207
# ('believ', 'utter'):0.07142857142857142
# ('utter', 'perfect'):0.5
# ('perfect', 'first'):0.09090909090909091
# ('first', 'part'):0.07142857142857142
# ('part', 'movi'):0.13333333333333333
# ('movi', 'begin'):0.004310344827586207
# ('begin', 'understand'):0.125
# ('understand', 'arthur'):0.06666666666666667
# ('arthur', 'person'):0.05555555555555555
# ('person', 'interact'):0.05
# ('interact', 'everyon'):1.0
# ('everyon', 'life'):0.08333333333333333
# ('life', 'good'):0.05555555555555555
# ('good', 'bad'):0.05454545454545454
# ('bad', 'whole'):0.05263157894736842
# ('point', 'charact'):0.05
# ('studi', 'evolut'):0.25
# ('evolut', 'far'):0.3333333333333333
# ('far', 'away'):0.14285714285714285
# ('away', 'one'):0.14285714285714285
# ('greatest', 'evolut'):0.2
# ('evolut', 'charact'):0.3333333333333333
# ('charact', 'ever'):0.01639344262295082
# ('movi', 'joaquin'):0.004310344827586207
# ('perform', 'far'):0.025
# ('far', 'best'):0.07142857142857142
# ('best', 'act'):0.06666666666666667
# ('act', 'seen'):0.023255813953488372
# ('movi', 'possibl'):0.004310344827586207
# ('possibl', 'last'):0.3333333333333333
# ('decad', 'see'):0.16666666666666666
# ('see', 'challeng'):0.03333333333333333
# ('challeng', 'person'):0.3333333333333333
# ('person', 'challeng'):0.05
# ('challeng', 'societi'):0.3333333333333333
# ('societi', 'complet'):0.058823529411764705
# ('complet', 'break'):0.07142857142857142
# ('break', 'time'):0.25
# ('time', 'joaquin'):0.024390243902439025
# ('joaquin', 'isn'):0.01818181818181818
# ('isn', 'act'):0.1
# ('act', 'revolv'):0.023255813953488372
# ('revolv', 'throughout'):0.2
# ('movi', 'anyon'):0.004310344827586207
# ('anyon', 'think'):0.125
# ('think', 'doesn'):0.04
# ('doesn', 'put'):0.1
# ('put', 'oscar'):0.07692307692307693
# ('win', 'perform'):0.1111111111111111
# ('perform', 'there'):0.025
# ('there', 'eat'):0.1111111111111111
# ('eat', 'mind'):0.25
# ('mind', 'ye'):0.2
# ('slow', 'start'):0.1
# ('start', 'couldn'):0.09090909090909091
# ('couldn', 'jump'):0.16666666666666666
# ('jump', 'joke'):0.5
# ('joke', 'chao'):0.006211180124223602
# ('chao', 'need'):0.5
# ('need', 'know'):0.05555555555555555
# ('know', 'came'):0.043478260869565216
# ('came', 'begin'):0.16666666666666666
# ('begin', 'whole'):0.125
# ('whole', 'compil'):0.09090909090909091
# ('compil', 'movi'):1.0
# ('movi', 'amaz'):0.004310344827586207
# ('amaz', 'complet'):0.07692307692307693
# ('complet', 'oscar'):0.07142857142857142
# ('oscar', 'deserv'):0.043478260869565216
# ('deserv', 'perform'):0.09090909090909091
# ('joaquin', 'choreographi'):0.01818181818181818
# ('choreographi', 'cinematographi'):1.0
# ('cinematographi', 'score'):0.0625
# ('score', 'everyth'):0.07142857142857142
# ('everyth', 'perfect'):0.08333333333333333
# ('perfect', 'harmoni'):0.09090909090909091
# ('harmoni', 'may'):1.0
# ('may', 'lot'):0.1111111111111111
# ('lot', 'controversi'):0.07692307692307693
# ('controversi', 'surround'):0.3333333333333333
# ('surround', 'movi'):1.0
# ('movi', 'team'):0.004310344827586207
# ('team', 'put'):1.0
# ('put', 'togeth'):0.07692307692307693
# ('togeth', 'perfect'):1.0
# ('perfect', 'movi'):0.09090909090909091
# ('movi', 'piti'):0.004310344827586207
# ('piti', 'can'):0.5
# ('can', 'appreci'):0.1
# ('appreci', 'tear'):0.25
# ('tear', 'sweat'):0.5
# ('sweat', 'emot'):1.0
# ('went', 'make'):0.07142857142857142
# ('make', 'movi'):0.075
# ('movi', 'alway'):0.004310344827586207
# ('alway', 'one'):0.25
# ('one', 'side'):0.0196078431372549
# ('side', 'movi'):0.3333333333333333
# ('movi', 'refer'):0.004310344827586207
# ('refer', 'marvel'):0.2
# ('marvel', 'do'):0.3333333333333333
# ('do', 'feel'):0.05263157894736842
# ('like', 'marvel'):0.016129032258064516
# ('marvel', 'soon'):0.3333333333333333
# ('better', 'overal'):0.045454545454545456
# ('overal', 'move'):0.14285714285714285
# ('move', 'do'):0.05128205128205128
# ('do', 'put'):0.05263157894736842
# ('put', 'trash'):0.07692307692307693
# ('trash', 'joke'):0.5
# ('joke', 'far'):0.006211180124223602
# ('away', 'favorit'):0.14285714285714285
# ('favorit', 'comic'):0.3333333333333333
# ('even', 'though'):0.06451612903225806
# ('though', 'take'):0.1
# ('take', 'complet'):0.041666666666666664
# ('complet', 'differ'):0.14285714285714285
# ('differ', 'spin'):0.0625
# ('spin', 'comic'):0.5
# ('comic', 'move'):0.043478260869565216
# ('move', 'appreci'):0.02564102564102564
# ('appreci', 'evolut'):0.25
# ('evolut', 'appreci'):0.3333333333333333
# ('appreci', 'movi'):0.25
# ('movi', 'action'):0.004310344827586207
# ('action', 'movi'):0.058823529411764705
# ('realli', 'lip'):0.029411764705882353
# ('lip', 'tear'):0.5
# ('tear', 'emot'):0.5
# ('emot', 'one'):0.1111111111111111
# ('one', 'movi'):0.0196078431372549
# ('movi', 'ad'):0.004310344827586207
# ('ad', 'wild'):0.5
# ('wild', 'suspens'):0.5
# ('suspens', 'kick'):0.5
# ('kick', 'comic'):1.0
# ('movi', 'done'):0.004310344827586207
# ('done', 'incred'):0.125
# ('incred', 'ride'):0.14285714285714285
# ('ride', 'almost'):0.3333333333333333
# ('almost', 'motionless'):0.1
# ('motionless', 'throughout'):1.0
# ('throughout', 'watch'):0.1111111111111111
# ('watch', 'awe'):0.022222222222222223
# ('awe', 'perform'):1.0
# ('lifetim', 'transit'):0.5
# ('transit', 'troubl'):0.3333333333333333
# ('troubl', 'man'):0.5
# ('man', 'monster'):0.09090909090909091
# ('monster', 'found'):0.25
# ('found', 'score'):0.25
# ('score', 'directli'):0.07142857142857142
# ('directli', 'drove'):0.5
# ('drove', 'goosebump'):1.0
# ('goosebump', 'cinematographi'):1.0
# ('cinematographi', 'made'):0.0625
# ('like', 'fli'):0.016129032258064516
# ('fli', 'gothic'):1.0
# ('gothic', 'look'):0.2
# ('look', 'arthur'):0.05555555555555555
# ('arthur', 'wast'):0.05555555555555555
# ('wast', 'de'):0.16666666666666666
# ('de', 'no'):0.8
# ('no', 'gave'):0.2
# ('gave', 'nod'):1.0
# ('nod', 'merri'):0.3333333333333333
# ('merri', 'lewi'):1.0
# ('lewi', 'ignor'):1.0
# ('ignor', 'do'):0.2
# ('do', 'ignor'):0.05263157894736842
# ('ignor', 'batman'):0.2
# ('batman', 'work'):0.05263157894736842
# ('work', 'art'):0.25
# ('art', 'right'):0.14285714285714285
# ('right', 'movi'):0.1
# ('movi', 'answer'):0.004310344827586207
# ('answer', 'questionwhat'):0.3333333333333333
# ('questionwhat', 'joke'):1.0
# ('joke', 'real'):0.006211180124223602
# ('real', 'life'):0.13333333333333333
# ('life', 'charact'):0.05555555555555555
# ('charact', 'great'):0.01639344262295082
# ('great', 'deep'):0.034482758620689655
# ('deep', 'move'):0.125
# ('move', 'stori'):0.05128205128205128
# ('stori', 'life'):0.02857142857142857
# ('life', 'journey'):0.05555555555555555
# ('journey', 'man'):0.5
# ('man', 'who'):0.09090909090909091
# ('who', 'suffer'):0.25
# ('suffer', 'psycholog'):0.14285714285714285
# ('psycholog', 'issu'):0.125
# ('issu', 'neglect'):0.2
# ('neglect', 'build'):0.3333333333333333
# ('build', 'rude'):0.1
# ('rude', 'human'):1.0
# ('human', 'push'):0.3333333333333333
# ('push', 'man'):0.5
# ('man', 'complet'):0.09090909090909091
# ('complet', 'mad'):0.07142857142857142
# ('mad', 'although'):0.16666666666666666
# ('although', 'accur'):0.25
# ('accur', 'comic'):0.25
# ('book', 'adapt'):0.1111111111111111
# ('adapt', 'to'):1.0
# ('to', 'seri'):0.5
# ('seri', 'movi'):1.0
# ('movi', 'yet'):0.008620689655172414
# ('yet', 'fresh'):0.14285714285714285
# ('fresh', 'uniqu'):0.5
# ('uniqu', 'take'):0.3333333333333333
# ('take', 'charact'):0.041666666666666664
# ('charact', 'clown'):0.01639344262295082
# ('crime', 'realist'):0.14285714285714285
# ('realist', 'approach'):0.125
# ('approach', 'believ'):0.5
# ('believ', 'joaquin'):0.07142857142857142
# ('amaz', 'perform'):0.07692307692307693
# ('joke', 'manag'):0.006211180124223602
# ('manag', 'bring'):0.5
# ('bring', 'real'):0.16666666666666666
# ('life', 'lookalik'):0.05555555555555555
# ('lookalik', 'earli'):1.0
# ('earli', 'version'):0.5
# ('joke', 'although'):0.006211180124223602
# ('although', 'comic'):0.25
# ('book', 'accur'):0.1111111111111111
# ('accur', 'feel'):0.25
# ('feel', 'decent'):0.02564102564102564
# ('decent', 'foundat'):0.3333333333333333
# ('foundat', 'joke'):1.0
# ('joke', '2'):0.006211180124223602
# ('2', 'true'):0.09090909090909091
# ('true', 'heart'):0.125
# ('heart', 'origin'):1.0
# ('origin', 'version'):0.07692307692307693
# ('version', 'movabl'):0.09090909090909091
# ('movabl', 'villain'):1.0
# ('villain', 'movi'):0.14285714285714285
# ('great', 'piec'):0.034482758620689655
# ('piec', 'filmmak'):0.16666666666666666
# ('filmmak', 'aspect'):0.5
# ('aspect', 'plot'):0.25
# ('plot', 'interest'):0.05
# ('interest', 'believ'):0.125
# ('believ', 'mani'):0.07142857142857142
# ('mani', 'relat'):0.03225806451612903
# ('relat', 'act'):0.14285714285714285
# ...
# ('grip', 'good'):0.3333333333333333
# ('part', 'come'):0.06666666666666667
# ('chair', 'half'):0.3333333333333333
# ('half', 'price'):0.25
# ('price', 'snack'):1.0
# ('snack', 'phoenix'):0.5
# ('phoenix', 'top'):0.016129032258064516
# ('top', 'good'):0.3333333333333333
# ('way', 'phoenix'):0.030303030303030304
# ('phoenix', 'stop'):0.016129032258064516
# ('stop', 'danc'):0.3333333333333333
# ('danc', 'denisov'):0.16666666666666666
# ('denisov', 'play'):1.0
# ('play', 'anoth'):0.0625
# ('anoth', 'version'):0.14285714285714285
# ('version', 'part'):0.09090909090909091
# ('part', 'play'):0.06666666666666667
# ('play', 'past'):0.0625
# ('past', 'year'):0.16666666666666666
# ('year', '2'):0.07142857142857142
# ('2', 'star'):0.09090909090909091
# ('star', 'chair'):0.125
# ('chair', '1'):0.3333333333333333
# ('star', 'snack'):0.125
# ('snack', '1'):0.5
# ('star', 'wast'):0.125
# ('wast', 'day'):0.16666666666666666
# ('day', 'batman'):0.25
# ('batman', 'fan'):0.05263157894736842
# ('fan', 'particularli'):0.3333333333333333
# ('particularli', 'fond'):0.5
# ('fond', 'joaquin'):1.0
# ('phoenix', 'movi'):0.016129032258064516
# ('movi', 'truli'):0.004310344827586207
# ('truli', 'except'):0.14285714285714285
# ('except', 'start'):0.16666666666666666
# ('start', 'slow'):0.09090909090909091
# ('slow', 'built'):0.1
# ('built', 'viscer'):1.0
# ('viscer', 'satisfi'):1.0
# ('satisfi', 'crescent'):0.3333333333333333
# ('crescent', 'never'):1.0
# ('never', 'thought'):0.07692307692307693
# ('would', 'foot'):0.03225806451612903
# ('foot', 'joke'):0.5
# ('joke', 'found'):0.006211180124223602
# ('found', 'throughout'):0.25
# ('joke', 'pain'):0.006211180124223602
# ('pain', 'palpabl'):0.16666666666666666
# ('palpabl', 'fill'):1.0
# ('fill', 'oscar'):0.3333333333333333
# ('oscar', 'pool'):0.043478260869565216
# ('pool', 'card'):0.3333333333333333
# ('card', 'right'):1.0
# ('right', 'is'):0.1
# ('is', 'movi'):0.3333333333333333
# ('dark', 'violent'):0.03571428571428571
# ('violent', 'decidedli'):0.125
# ('decidedli', 'super'):1.0
# ('movi', 'leav'):0.004310344827586207
# ('leav', 'kiss'):0.14285714285714285
# ('kiss', 'home'):0.3333333333333333
# ('home', 'husband'):0.5
# ('husband', 'went'):1.0
# ('see', 'film'):0.03333333333333333
# ('film', 'found'):0.011627906976744186
# ('found', 'extrem'):0.25
# ('extrem', 'depress'):0.25
# ('depress', 'moreov'):0.2
# ('moreov', 'everyth'):1.0
# ('everyth', 'caricatur'):0.08333333333333333
# ('caricatur', 'could'):1.0
# ('could', 'normal'):0.04
# ('normal', 'might'):0.3333333333333333
# ('might', 'say'):0.14285714285714285
# ('say', 'given'):0.027777777777777776
# ('given', 'depict'):0.3333333333333333
# ('depict', 'life'):0.5
# ('life', 'comic'):0.05555555555555555
# ('book', 'clown'):0.1111111111111111
# ('clown', 'christoph'):0.08333333333333333
# ('christoph', 'woman'):1.0
# ('woman', 'director'):0.5
# ('director', 'famou'):0.125
# ('famou', 'batman'):1.0
# ('batman', 'trilog'):0.05263157894736842
# ('trilog', 'said'):0.3333333333333333
# ('said', 'produc'):0.14285714285714285
# ('produc', 'movi'):0.2
# ('would', 'useless'):0.03225806451612903
# ('useless', 'simpli'):1.0
# ('simpli', 'come'):0.25
# ('come', 'horror'):0.06666666666666667
# ('le', 'show'):0.14285714285714285
# ('show', 'career'):0.058823529411764705
# ('career', 'your'):1.0
# ('your', 'told'):0.16666666666666666
# ('told', 'giant'):0.0625
# ('giant', 'monster'):1.0
# ('monster', 'wood'):0.25
# ('wood', 'eat'):1.0
# ('eat', 'peopl'):0.25
# ('peopl', 'you'):0.02127659574468085
# ('you', 'laugh'):0.16666666666666666
# ('laugh', 'believ'):0.05263157894736842
# ('believ', 'you'):0.07142857142857142
# ('you', 'imagin'):0.16666666666666666
# ('imagin', 'horribl'):0.5
# ('horribl', 'monster'):0.2
# ('monster', 'horribl'):0.25
# ('horribl', 'accord'):0.2
# ('accord', 'other'):1.0
# ('other', 'show'):0.25
# ('u', 'never'):0.06666666666666667
# ('never', 'horribl'):0.07692307692307693
# ('horribl', 'u'):0.2
# ('u', 'imagin'):0.06666666666666667
# ('imagin', 'make'):0.5
# ('make', 'thing'):0.025
# ('thing', 'realli'):0.05
# ('realli', 'aw'):0.029411764705882353
# ('aw', 'sink'):0.25
# ('sink', 'worst'):1.0
# ('worst', 'possibl'):0.25
# ('possibl', 'melodrama'):0.3333333333333333
# ('melodrama', 'psychopath'):1.0
# ('psychopath', 'mistreat'):0.3333333333333333
# ('mistreat', 'childhood'):0.5
# ('childhood', 'mock'):0.5
# ('mock', 'adolesc'):1.0
# ('adolesc', 'misunderstood'):1.0
# ('misunderstood', 'adulthood'):0.3333333333333333
# ('adulthood', 'without'):1.0
# ('without', 'ever'):0.07692307692307693
# ('ever', 'anyon'):0.0625
# ('anyon', 'help'):0.125
# ('help', 'effect'):0.2
# ('effect', 'vast'):0.3333333333333333
# ('vast', 'major'):0.5
# ('major', 'born'):1.0
# ('born', 'miss'):1.0
# ('miss', 'bolt'):0.14285714285714285
# ('bolt', 'head'):1.0
# ('head', 'someth'):1.0
# ('someth', 'wrong'):0.08333333333333333
# ('wrong', 'start'):0.1
# ('start', 'director'):0.09090909090909091
# ('director', 'want'):0.125
# ('want', 'make'):0.03225806451612903
# ('make', 'u'):0.025
# ('u', 'cri'):0.06666666666666667
# ('cri', 'portray'):0.2
# ('portray', 'roughli'):0.09090909090909091
# ('roughli', 'cartoon'):1.0
# ('cartoon', 'miseri'):1.0
# ('miseri', 'everyth'):0.5
# ('everyth', 'bold'):0.08333333333333333
# ('bold', 'capit'):1.0
# ('capit', 'letter'):1.0
# ('letter', 'undermin'):1.0
# ('undermin', 'highlight'):0.5
# ('highlight', 'sure'):0.5
# ('sure', 'fulli'):0.08333333333333333
# ('fulli', 'understood'):0.5
# ('understood', 'main'):0.5
# ('charact', 'didn'):0.01639344262295082
# ('didn', 'easi'):0.1
# ('easi', 'life'):0.2
# ('life', 'societi'):0.05555555555555555
# ('societi', 'rotten'):0.058823529411764705
# ('rotten', 'revolt'):1.0
# ('revolt', 'suicid'):1.0
# ('suicid', 'desper'):0.3333333333333333
# ('desper', 'kill'):0.5
# ('kill', 'put'):0.125
# ('put', 'end'):0.07692307692307693
# ('end', 'seriou'):0.0625
# ('seriou', 'ask'):0.3333333333333333
# ('ask', 'ledger'):0.25
# ('joke', 'that'):0.006211180124223602
# ('good', 'question'):0.01818181818181818
# ('question', 'in'):0.5
# ('in', 'worri'):0.1
# ('worri', 'futur'):1.0
# ('futur', 'charact'):0.25
# ('charact', 'especi'):0.01639344262295082
# ('especi', 'actor'):0.3333333333333333
# ('actor', 'want'):0.05555555555555555
# ('want', 'play'):0.03225806451612903
# ('play', 'term'):0.0625
# ('term', 'actor'):1.0
# ('actor', 'perform'):0.05555555555555555
# ('perform', 'that'):0.025
# ('that', 'joaquim'):0.06666666666666667
# ('joaquim', 'phoenix'):1.0
# ('phoenix', 'push'):0.016129032258064516
# ('push', 'extrem'):0.5
# ('extrem', 'film'):0.25
# ('film', 'rememb'):0.011627906976744186
# ('rememb', 'actor'):0.25
# ('actor', 'play'):0.05555555555555555
# ('play', 'social'):0.0625
# ('social', 'visit'):0.3333333333333333
# ('visit', 'lover'):0.5
# ('lover', 'unabl'):1.0
# ('unabl', 'make'):0.5
# ('make', 'friend'):0.025
# ('friend', 'depress'):1.0
# ('depress', 'peopl'):0.2
# ('peopl', 'verg'):0.02127659574468085
# ('verg', 'nervou'):1.0
# ('nervou', 'breakdown'):1.0
# ('breakdown', 'misunderstood'):1.0
# ('misunderstood', 'gun'):0.3333333333333333
# ('gun', 'son'):0.2
# ('son', 'reject'):0.3333333333333333
# ('reject', 'father'):0.5
# ('father', 'rebel'):1.0
# ('rebel', 'etc'):1.0
# ('etc', 'short'):0.25
# ('short', 'play'):0.14285714285714285
# ('play', 'tortur'):0.0625
# ('tortur', 'soul'):0.5
# ('soul', 'even'):1.0
# ('even', 'play'):0.03225806451612903
# ('play', 'guy'):0.0625
# ('guy', 'fall'):0.14285714285714285
# ('love', 'comput'):0.1
# ('comput', 'can'):1.0
# ('get', 'along'):0.03225806451612903
# ('along', 'real'):0.5
# ('real', 'girlfriend'):0.06666666666666667
# ('girlfriend', 'normal'):1.0
# ('normal', 'know'):0.3333333333333333
# ('know', 'play'):0.043478260869565216
# ('play', 'crazi'):0.0625
# ('crazi', 'clown'):0.125
# ('clown', 'talent'):0.08333333333333333
# ('talent', 'consid'):0.16666666666666666
# ('consid', 'fact'):0.1111111111111111
# ('fact', 'seem'):0.16666666666666666
# ('seem', 'unabl'):0.08333333333333333
# ('unabl', 'play'):0.5
# ('play', 'much'):0.0625
# ('much', 'el'):0.03571428571428571
# ('el', 'simplist'):0.16666666666666666
# ('simplist', 'gloomi'):1.0
# ('gloomi', 'deduct'):1.0
# ('deduct', 'societi'):0.3333333333333333
# ('societi', 'alreadi'):0.058823529411764705
# ('alreadi', 'claim'):0.2
# ('claim', 'victim'):0.2
# ('victim', 'peopl'):0.2
# ('peopl', 'dress'):0.02127659574468085
# ('dress', 'clown'):1.0
# ('clown', 'ransack'):0.08333333333333333
# ('ransack', 'everyth'):1.0
# ('everyth', 'street'):0.08333333333333333
# ('street', 'cinema'):1.0
# ('cinema', 'film'):0.09090909090909091
# ('film', 'shown'):0.011627906976744186
# ('shown', 'seem'):0.3333333333333333
# ('seem', 'visit'):0.08333333333333333
# ('visit', 'want'):0.5
# ('want', 'believ'):0.03225806451612903
# ('believ', 'joke'):0.07142857142857142
# ('joke', 'misfortun'):0.006211180124223602
# ('misfortun', 'depend'):1.0
# ('depend', 'everyth'):0.5
# ('everyth', 'everyon'):0.08333333333333333
# ('el', 'happi'):0.16666666666666666
# ('happi', 'couldn'):0.2
# ('couldn', 'certainli'):0.16666666666666666
# ('certainli', 'anyway'):1.0
# ('anyway', 'dont'):0.3333333333333333
# ('dont', 'believ'):0.03225806451612903
# ('believ', 'good'):0.07142857142857142
# ('thing', 'said'):0.05
# ('said', 'movi'):0.14285714285714285
# ('movi', 'feel'):0.004310344827586207
# ('bit', 'sort'):0.125
# ('sort', 'dont'):1.0
# ('dont', 'go'):0.03225806451612903
# ('see', 'you'):0.03333333333333333
# ('you', 'make'):0.16666666666666666
# ('make', 'unhappi'):0.025
# ('unhappi', 'film'):1.0
# ('film', 'that'):0.011627906976744186
# ('that', 'realli'):0.06666666666666667
# ('realli', 'worth'):0.029411764705882353
# ('worth', 'masterpiec'):0.14285714285714285
# ('masterpiec', 'one'):0.05
# ('decad', 'act'):0.16666666666666666
# ('direct', 'set'):0.0625
# ('set', 'photographi'):0.14285714285714285
# ('photographi', 'soundtrack'):1.0
# ('soundtrack', 'year'):0.25
# ('year', 'film'):0.07142857142857142
# ('film', 'cult'):0.011627906976744186
# ('cult', 'one'):1.0
# ('one', 'bore'):0.0196078431372549
# ('bore', 'realli'):0.05
# ('realli', 'can'):0.029411764705882353
# ('can', 'understand'):0.1
# ('understand', 'hope'):0.06666666666666667
# ('hope', 'one'):0.045454545454545456
# ('move', 'ever'):0.02564102564102564
# ('seen', 'ok'):0.034482758620689655
# ('ok', 'mayb'):0.5
# ('mayb', 'hope'):0.1111111111111111
# ('hope', 'surround'):0.045454545454545456
# ('movi', 'kill'):0.004310344827586207
# ('kill', 'masterpiec'):0.125
# ('masterpiec', 'ok'):0.05
# ('ok', 'film'):0.5
# ('star', 'way'):0.125
# ('way', 'mani'):0.030303030303030304
# ('mani', 'wa'):0.03225806451612903
# ('wa', 'actual'):0.3333333333333333
# ('actual', 'agre'):0.047619047619047616
# ('agre', 'actual'):0.3333333333333333
# ('actual', 'critic'):0.047619047619047616
# ('critic', 'grade'):0.125
# ('grade', 'film'):0.3333333333333333
# ('film', 'didn'):0.011627906976744186
# ('didn', 'realli'):0.1
# ('know', 'much'):0.043478260869565216
# ('movi', 'hadn'):0.004310344827586207
# ('hadn', 'seen'):0.5
# ('trailer', 'anyth'):0.125
# ('anyth', 'decid'):0.09090909090909091
# ('decid', 'give'):1.0
# ('give', 'go'):0.05
# ('go', 'stone'):0.041666666666666664
# ('stone', 'mate'):1.0
# ('mate', 'steve'):1.0
# ('steve', 'actual'):0.5
# ('actual', 'got'):0.047619047619047616
# ('got', 'ticket'):0.125
# ('ticket', 'differ'):1.0
# ('differ', 'movi'):0.0625
# ('movi', 'couldn'):0.004310344827586207
# ('couldn', 'find'):0.16666666666666666
# ('find', 'screen'):0.2
# ('screen', 'end'):0.16666666666666666
# ('end', 'screen'):0.0625
# ('screen', 'show'):0.16666666666666666
# ('show', 'joke'):0.058823529411764705
# ('want', 'til'):0.03225806451612903
# ('til', '45'):1.0
# ('45', 'minut'):1.0
# ('minut', 'realis'):0.2
# ('realis', 'movi'):1.0
# ('good', 'couldn'):0.01818181818181818
# ('couldn', 'understand'):0.16666666666666666
# ('understand', 'lot'):0.06666666666666667
# ('lot', 'certain'):0.07692307692307693
# ('certain', 'actor'):0.3333333333333333
# ('actor', 'say'):0.05555555555555555
# ('say', 'realli'):0.027777777777777776
# ('realli', 'mumbl'):0.029411764705882353
# ('mumbl', 'low'):1.0
# ('low', 'qualiti'):0.25
# ('qualiti', 'stori'):0.25
# ('stori', 'confus'):0.02857142857142857
# ('confus', 'hard'):0.3333333333333333
# ('hard', 'keep'):0.14285714285714285
# ('keep', 'track'):0.08333333333333333
# ('track', 'who'):0.5
# ('who', 'there'):0.25
# ('lot', 'scene'):0.07692307692307693
# ('scene', 'liter'):0.05555555555555555
# ('except', 'peopl'):0.16666666666666666
# ('peopl', 'talk'):0.02127659574468085
# ('talk', 'walk'):0.16666666666666666
# ('walk', 'corridor'):0.25
# ('corridor', 'whisper'):1.0
# ('whisper', 'mate'):1.0
# ('steve', 'hour'):0.5
# ('hour', 'see'):0.07692307692307693
# ('see', 'thought'):0.03333333333333333
# ('thought', 'bad'):0.07142857142857142
# ('bad', 'fallen'):0.05263157894736842
# ('fallen', 'asleep'):1.0
# ('asleep', 'good'):0.5
# ('act', 'deeper'):0.023255813953488372
# ('deeper', 'play'):0.5
# ('play', 'joke'):0.0625
# ('good', 'also'):0.01818181818181818
# ('also', 'funni'):0.058823529411764705
# ('funni', 'scene'):0.3333333333333333
# ('scene', 'near'):0.05555555555555555
# ('near', 'end'):0.3333333333333333
# ('end', 'movi'):0.0625
# ('movi', 'overlay'):0.004310344827586207
# ('overlay', 'long'):0.25
# ('long', 'complex'):0.09090909090909091
# ('complex', 'enough'):0.5
# ('enough', 'action'):0.2
# ('action', 'poor'):0.058823529411764705
# ('film', 'direct'):0.011627906976744186
# ('direct', 'produc'):0.0625
# ('produc', 'poorli'):0.2
# ('poorli', 'opportun'):0.3333333333333333
# ('opportun', 'take'):0.3333333333333333
# ('take', 'advantag'):0.041666666666666664
# ('advantag', 'incred'):1.0
# ('incred', 'joaquin'):0.14285714285714285
# ('phoenix', 'blown'):0.016129032258064516
# ('blown', 'gratuit'):1.0
# ('gratuit', 'violenc'):0.5
# ('violenc', 'misplac'):0.1
# ('misplac', 'violenc'):1.0
# ('violenc', 'wrong'):0.1
# ('wrong', 'approach'):0.1
# ('approach', 'joke'):0.5
# ('joke', 'disappoint'):0.006211180124223602
# ('disappoint', 'connect'):0.25
# ('connect', 'viewer'):0.3333333333333333
# ('viewer', 'film'):0.3333333333333333
# ('film', 'wander'):0.011627906976744186
# ('wander', 'long'):0.5
# ('long', 'period'):0.09090909090909091
# ('period', 'ton'):0.5
# ('ton', 'forag'):1.0
# ('forag', 'hit'):1.0
# ('hit', 'cut'):0.2
# ('cut', 'room'):0.3333333333333333
# ('room', 'floor'):1.0
# ('floor', 'realli'):1.0
# ('realli', 'want'):0.029411764705882353
# ('want', 'stir'):0.03225806451612903
# ('stir', 'creep'):1.0
# ('creep', 'connect'):1.0
# ('connect', 'joaquin'):0.3333333333333333
# ('want', 'look'):0.03225806451612903
# ('look', 'joaquin'):0.05555555555555555
# ('joaquin', 'moment'):0.01818181818181818
# ('like', 'gladiat'):0.016129032258064516
# ('gladiat', 'disappoint'):0.5
# ('disappoint', 'now'):0.25
# ('now', 'movi'):0.2
# ('movi', 'admit'):0.004310344827586207
# ('admit', 'first'):1.0
# ('first', 'heard'):0.07142857142857142
# ('heard', 'joaquin'):0.3333333333333333
# ('phoenix', 'go'):0.016129032258064516
# ('go', 'joke'):0.041666666666666664
# ('joke', 'surpris'):0.006211180124223602
# ('surpris', 'want'):0.16666666666666666
# ('sure', 'go'):0.08333333333333333
# ('go', 'pull'):0.041666666666666664
# ('pull', 'hope'):0.3333333333333333
# ('hope', 'want'):0.045454545454545456
# ('want', 'go'):0.03225806451612903
# ('go', 'anoth'):0.041666666666666664
# ('anoth', 'chees'):0.14285714285714285
# ('chees', 'condit'):0.5
# ('condit', 'full'):0.3333333333333333
# ('full', 'fluff'):0.25
# ('fluff', 'realist'):0.5
# ('realist', 'explan'):0.125
# ('explan', 'joke'):1.0
# ('joke', 'came'):0.006211180124223602
# ('came', 'one'):0.16666666666666666
# ('one', 'adult'):0.0196078431372549
# ('adult', 'son'):0.3333333333333333
# ('son', 'wouldn'):0.3333333333333333
# ('wouldn', 'keep'):0.25
# ('keep', 'nudg'):0.08333333333333333
# ('nudg', 'wake'):1.0
# ('wake', 'pleasantli'):0.3333333333333333
# ('pleasantli', 'surpris'):1.0
# ('surpris', 'well'):0.16666666666666666
# ('well', 'told'):0.07692307692307693
# ('phillip', 'version'):0.1
# ('version', 'play'):0.09090909090909091
# ('joaquin', 'act'):0.01818181818181818
# ('superb', 'could'):0.3333333333333333
# ('could', 'feel'):0.04
# ('feel', 'anguish'):0.02564102564102564
# ('anguish', 'charact'):1.0
# ('charact', 'go'):0.01639344262295082
# ('go', 'right'):0.041666666666666664
# ('right', 'point'):0.1
# ('point', 'lost'):0.05
# ('lost', 'mind'):0.3333333333333333
# ('mind', 'excel'):0.2
# ('excel', 'well'):0.16666666666666666
# ('well', 'act'):0.07692307692307693
# ('act', 'movi'):0.023255813953488372
# ('almost', 'forget'):0.1
# ('forget', 'deriv'):0.2
# ('deriv', 'do'):1.0
# ('movi', 'poorli'):0.004310344827586207
# ('poorli', 'done'):0.3333333333333333
# ('done', 'tell'):0.125
# ('tell', 'stori'):0.2
# ('stori', 'dark'):0.02857142857142857
# ('dark', 'movi'):0.03571428571428571
# ('show', 'problem'):0.058823529411764705
# ('problem', 'mental'):0.25

# %% [markdown]
# **1.3 Noun Phrases and relative probabilities of each review in terms of others**

# %%
whole_dataset = ''
index = []
i = 1
for line in df['After Lemmatization']:
  whole_dataset = whole_dataset + line
  value = 'Review-' + str(i)
  index.append(value)
  i += 1

# %%
from textblob import TextBlob
noun_phrases = []
frequency = []
for line in df['After Lemmatization']:
  blob = TextBlob(line)
  for nouns in blob.noun_phrases:
    noun_phrases.append(nouns)
for word in noun_phrases:
  noun_phrases_freq = []
  for line in df['After Lemmatization']:
    noun_phrases_freq.append(line.count(word) / whole_dataset.count(word))
  frequency.append(noun_phrases_freq)
noun_phrases_df = pd.DataFrame(frequency).T
noun_phrases_df.columns = list(noun_phrases)
noun_phrases_df.index = index
noun_phrases_df
# Out:
#             everi movi  impact joaquin  ...  movi poorli  dark movi show problem
# Review-1           1.0             1.0  ...          0.0                     0.0
# Review-2           0.0             0.0  ...          0.0                     0.0
# Review-3           0.0             0.0  ...          0.0                     0.0
# Review-4           0.0             0.0  ...          0.0                     0.0
# Review-5           0.0             0.0  ...          0.0                     0.0
# ...                ...             ...  ...          ...                     ...
# Review-121         0.0             0.0  ...          0.0                     0.0
# Review-122         0.0             0.0  ...          0.0                     0.0
# Review-123         0.0             0.0  ...          0.0                     0.0
# Review-124         0.0             0.0  ...          0.0                     0.0
# Review-125         0.0             0.0  ...          1.0                     1.0
#
# [125 rows x 1168 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (40 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %% [markdown]
# **2.1 TF-IDF**

# %%
# Write your code here

import math
def tf_idf_value(sentence,word):
  size = len(sentence.split(" "))
  tf_value = sentence.count(word)/size
  idf_value = 0
  if(tf_value!=0):
    idf_value = math.log(size)/sentence.count(word)
  else:
    return 0;
  return tf_value*idf_value

sentences = df["Spelling Correction"].values.tolist()
tokens_list = set([j for i in sentences for j in i.split(" ")])
tf_idf = pd.DataFrame(tokens_list,columns=["token"])
count = 0
for i in sentences:
  tf_idf[str(count)] = tf_idf["token"].apply(lambda x : tf_idf_value(i,x))
  count+=1

tf_idf
# Out:
#           token         0         1         2  ...  121       122       123      124
# 0                0.081918  0.093937  0.055855  ...  0.0  0.084592  0.067391  0.21799
# 1          edge  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.000000  0.00000
# 2        topics  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.000000  0.00000
# 3     fantastic  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.000000  0.00000
# 4        recoil  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.000000  0.00000
# ...         ...       ...       ...       ...  ...  ...       ...       ...      ...
# 2275      ideas  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.000000  0.00000
# 2276    gripped  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.000000  0.00000
# 2277     seeing  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.000000  0.00000
# 2278  wandering  0.000000  0.000000  0.000000  ...  0.0  0.084592  0.000000  0.00000
# 2279       save  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.000000  0.00000
#
# [2280 rows x 126 columns]

# %% [markdown]
# **2.2 Ranking using cosine similarity**

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
query_sentence = 'The perfect portrait of a decline to insanity" & Joaquin Phoenix portrays this flawlessly in a performance of a lifetime. Choreographed impeccably by Todd Phillips & is nothing short of breathtaking. The cinematography & backdrop ideology of such an original film for such a complex character is only complimented by the superb soundtrack & acting. A hauntingly beautiful film & A Definate 10/10. Edit: Bring on part 2 plssssss!. We all want it!.'
X_list = word_tokenize(query_sentence)
sw = stopwords.words('english') 
X_set = {w for w in X_list if not w in sw}  
def compute_vector(X_set, Y_set):
  rvector = X_set.union(Y_set)
  l1 =[];l2 =[]
  for w in rvector: 
      if w in X_set: l1.append(1)
      else: l1.append(0) 
      if w in Y_set: l2.append(1) 
      else: l2.append(0)
  return rvector, l1, l2
def compute_cosine(rvector, l1, l2):
  c = 0
  for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
  cosine = c / float((sum(l1)*sum(l2))**0.5) 
  return cosine
similarity_list = []
for sentence in df['Spelling Correction']:
  Y_list = word_tokenize(sentence)
  Y_set = {w for w in Y_list if not w in sw}
  rvector, l1, l2 = compute_vector(X_set, Y_set)
  try:
    similarity = compute_cosine(rvector, l1, l2)
  except ZeroDivisionError:
    similarity = 'None'
  similarity_list.append(similarity)
cosine_dataframe = pd.DataFrame(list(zip(df['Review'],similarity_list)), columns=['Reviews','Cosine Similarity'])
cosine_dataframe
# Out:
#                                                Reviews Cosine Similarity
# 0    Every once in a while a movie comes, that trul...         0.0434783
# 1    This is a movie that only those who have felt ...         0.0256664
# 2    Truly a masterpiece, The Best Hollywood film o...         0.0761387
# 3    Joaquin Phoenix gives a tour de force performa...         0.0227508
# 4    Most of the time movies are anticipated like t...         0.0230266
# ..                                                 ...               ...
# 120  I didnt really know much about this movie. I h...         0.0695048
# 121                                                                 None
# 122  Film was directed and produced poorly. Opportu...         0.0472192
# 123  Wow, what a movie! I have to admit, When I fir...         0.0834058
# 124  This movie is poorly done as to how it tells t...                 0
#
# [125 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file

# Link: https://github.com/swethak00/SwethaKanakamedala_INFO5731_Spring2021/blob/main/joker_reviews.csv
